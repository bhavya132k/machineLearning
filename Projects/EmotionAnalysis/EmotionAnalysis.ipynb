# %% [markdown]
# # **Emotion Analysis using SVM and K-Means Clustering**

# %% [markdown]
# ### Objective: Develop an understanding of emotion recognition in text using Support Vector Machines (SVM) for classification and K-Means clustering for pattern discovery. This assignment will help you grasp the nuances of supervised and unsupervised learning techniques in Natural Language Processing (NLP).

# %%
# Cell 1 - Required library Instalations

# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install nltk
# %pip install imbalanced-learn
# %pip install gensim

# %%
# Cell 2 - Required packages downloaded

# nltk.download('punkt')
# Download WordNet data
# nltk.download('wordnet')

# %%
# Cell 3

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import string

# %%
# cell 4

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Step 1 - Load and familiarize yourself with the EmotionLines dataset.**

# %%
# cell 5

train_df = pd.read_json('friends_train.json')
test_df = pd.read_json('friends_test.json')
holdout_df = pd.read_json('friends_dev.json')

print("Training Dataset:")
print(train_df.head(3))

print("\nTest Dataset:")
print(test_df.head(3))

print("\nHoldout Dataset:")
print(holdout_df.head(3))
# Out:
# Training Dataset:
#                                                   0   \
# 0  {'speaker': 'Chandler', 'utterance': 'also I w...
# 1  {'speaker': 'Chandler', 'utterance': 'Hey, Mon...
# 2  {'speaker': 'Rachel', 'utterance': 'Hey!', 'em...
#
#                                                   1   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'Y...
# 1  {'speaker': 'Monica', 'utterance': 'Hey-hey-he...
# 2  {'speaker': 'Ross', 'utterance': 'Hi!', 'emoti...
#
#                                                   2   \
# 0  {'speaker': 'Chandler', 'utterance': 'That I d...
# 1  {'speaker': 'Chandler', 'utterance': 'Do I eve...
# 2  {'speaker': 'Rachel', 'utterance': 'What are y...
#
#                                                   3   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'S...
# 1  {'speaker': 'Monica', 'utterance': 'Chris says...
# 2  {'speaker': 'Ross', 'utterance': 'Ah y'know, t...
#
#                                                   4   \
# 0  {'speaker': 'Chandler', 'utterance': 'My dutie...
# 1  {'speaker': 'Chandler', 'utterance': 'No way!'...
# 2  {'speaker': 'Rachel', 'utterance': 'Oh.', 'emo...
#
#                                                   5   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'N...
# 1  {'speaker': 'Monica', 'utterance': 'Yeah, appa...
# 2  {'speaker': 'Ross', 'utterance': 'Hi.', 'emoti...
#
#                                                   6   \
# 0  {'speaker': 'Chandler', 'utterance': 'I see.',...
# 1  {'speaker': 'Chandler', 'utterance': 'Just cof...
# 2  {'speaker': 'Rachel', 'utterance': 'Hi.', 'emo...
#
#                                                   7   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'B...
# 1  {'speaker': 'Monica', 'utterance': 'Got me.', ...
# 2  {'speaker': 'Ross', 'utterance': 'Howd did it...
#
#                                                   8   \
# 0  {'speaker': 'Chandler', 'utterance': 'Good to ...
# 1  {'speaker': 'Chandler', 'utterance': 'Can I ge...
# 2  {'speaker': 'Rachel', 'utterance': 'Oh well, t...
#
#                                                   9   ...  \
# 0  {'speaker': 'The Interviewer', 'utterance': 'W...  ...
# 1  {'speaker': 'Monica', 'utterance': 'Hey, did y...  ...
# 2  {'speaker': 'Ross', 'utterance': 'Im so proud...  ...
#
#                                                   14  \
# 0  {'speaker': 'Joey', 'utterance': 'But then who...
# 1  {'speaker': 'Chandler', 'utterance': 'What, wh...
# 2  {'speaker': 'Rachel', 'utterance': 'Yeah.', 'e...
#
#                                                   15  \
# 0  {'speaker': 'Rachel', 'utterance': 'You know? ...
# 1  {'speaker': 'Phoebe', 'utterance': 'What?!', '...
# 2  {'speaker': 'Phoebe', 'utterance': 'Ameri-can....
#
#                                                   16  \
# 0  {'speaker': 'Joey', 'utterance': 'No-no-no-no,...
# 1  {'speaker': 'Phoebe', 'utterance': 'He was wit...
# 2  {'speaker': 'Sergei', 'utterance': 'Ameri-ccan...
#
#                                                   17  \
# 0  {'speaker': 'Rachel', 'utterance': 'No, I-I-I-...
# 1  {'speaker': 'Phoebe', 'utterance': 'Look,  'My...
# 2  {'speaker': 'Phoebe', 'utterance': 'Ameri-can....
#
#                                                   18  \
# 0  {'speaker': 'Joey', 'utterance': 'Ok!', 'emoti...
# 1  {'speaker': 'Phoebe', 'utterance': 'Now that I...
# 2  {'speaker': 'Sergei', 'utterance': 'Everybody!...
#
#                                                   19  \
# 0  {'speaker': 'Joey', 'utterance': 'All right, w...
# 1  {'speaker': 'Phoebe', 'utterance': 'He thinks ...
# 2                                               None
#
#                                                   20  \
# 0  {'speaker': 'Joey', 'utterance': 'I'm gonna se...
# 1  {'speaker': 'Chandler', 'utterance': 'You real...
# 2                                               None
#
#                                                   21  \
# 0  {'speaker': 'Joey', 'utterance': 'I'll see you...
# 1  {'speaker': 'Phoebe', 'utterance': 'Oh, totall...
# 2                                               None
#
#                                                   22    23
# 0  {'speaker': 'Rachel', 'utterance': 'Yeah, sure...  None
# 1  {'speaker': 'Joey', 'utterance': 'Done.', 'emo...  None
# 2                                               None  None
#
# [3 rows x 24 columns]
#
# Test Dataset:
#                                                   0   \
# 0  {'speaker': 'Mark', 'utterance': 'Why do all y...
# 1  {'speaker': 'Joey', 'utterance': 'Come on, Lyd...
# 2  {'speaker': 'Ross', 'utterance': 'Okay.', 'emo...
#
#                                                   1   \
# 0  {'speaker': 'Rachel', 'utterance': 'Oh. Thats...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Rachel', 'utterance': 'Ross, didn...
#
#                                                   2   \
# 0  {'speaker': 'Rachel', 'utterance': 'Y'know wha...
# 1  {'speaker': 'Joey', 'utterance': 'Push 'em out...
# 2  {'speaker': 'Ross', 'utterance': 'Uhh, yes I d...
#
#                                                   3   \
# 0  {'speaker': 'Ross', 'utterance': 'It didnt.',...
# 1  {'speaker': 'Joey', 'utterance': 'Push 'em out...
# 2  {'speaker': 'Ross', 'utterance': 'Okay, go lef...
#
#                                                   4   \
# 0  {'speaker': 'Frank', 'utterance': 'Okay, so wh...
# 1  {'speaker': 'Joey', 'utterance': 'Let's get th...
# 2  {'speaker': 'Rachel', 'utterance': 'Okay, y'kn...
#
#                                                   5   \
# 0  {'speaker': 'Joey', 'utterance': 'Now, wh-what...
# 1  {'speaker': 'Joey', 'utterance': 'Let's  I wa...
# 2  {'speaker': 'Ross', 'utterance': 'Oh okay, lif...
#
#                                                   6   \
# 0  {'speaker': 'Frank', 'utterance': 'Its so coo...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'Straight up ...
#
#                                                   7   \
# 0  {'speaker': 'Ross', 'utterance': 'Yeah, yeah.'...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'You can do i...
#
#                                                   8   \
# 0  {'speaker': 'Joey', 'utterance': 'Why cant I ...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'You can do i...
#
#                                                   9   ...  \
# 0  {'speaker': 'Ross', 'utterance': 'Dont ask me...  ...
# 1                                               None  ...
# 2  {'speaker': 'Ross', 'utterance': 'Okay.', 'emo...  ...
#
#                                                   14  \
# 0  {'speaker': 'Frank', 'utterance': 'Its out th...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Yes but too ...
#
#                                                   15  \
# 0  {'speaker': 'Joey', 'utterance': 'Then you hol...
# 1                                               None
# 2  {'speaker': 'Steve', 'utterance': 'Okay, fine,...
#
#                                                   16  \
# 0  {'speaker': 'Frank', 'utterance': 'All right, ...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Ugh, can you...
#
#                                                   17    18    19    20    21  \
# 0  {'speaker': 'Joey', 'utterance': 'All right, c...  None  None  None  None
# 1                                               None  None  None  None  None
# 2  {'speaker': 'Phoebe', 'utterance': 'Yeah. I re...  None  None  None  None
#
#      22    23
# 0  None  None
# 1  None  None
# 2  None  None
#
# [3 rows x 24 columns]
#
# Holdout Dataset:
#                                                   0   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Oh my God,...
# 1  {'speaker': 'Joey', 'utterance': 'Hey Estelle,...
# 2  {'speaker': 'Ross', 'utterance': 'Yes? Yes?! H...
#
#                                                   1   \
# 0  {'speaker': 'Monica', 'utterance': 'What?', 'e...
# 1  {'speaker': 'Estelle', 'utterance': 'Well! Wel...
# 2  {'speaker': 'Guy', 'utterance': 'Yeah, we were...
#
#                                                   2   \
# 0  {'speaker': 'Ross', 'utterance': 'Or! Or, we c...
# 1  {'speaker': 'Joey', 'utterance': 'What are you...
# 2  {'speaker': 'Ross', 'utterance': 'Oh-oh, your...
#
#                                                   3   \
# 0  {'speaker': 'Chandler', 'utterance': 'Youre a...
# 1  {'speaker': 'Estelle', 'utterance': 'Really?!'...
# 2  {'speaker': 'Ross', 'utterance': 'What exactly...
#
#                                                   4   \
# 0  {'speaker': 'Joey', 'utterance': 'Aww, man, no...
# 1  {'speaker': 'Joey', 'utterance': 'Yeah!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'Perhaps,  pe...
#
#                                                   5   \
# 0  {'speaker': 'Chandler', 'utterance': 'Now, the...
# 1  {'speaker': 'Estelle', 'utterance': 'Oh well, ...
# 2  {'speaker': 'Guy', 'utterance': 'Uhh.', 'emot...
#
#                                                   6   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Hey.', 'em...
# 1  {'speaker': 'Gary', 'utterance': 'Okay, you gu...
# 2  {'speaker': 'Ross', 'utterance': 'Ah AhGet o...
#
#                                                   7   \
# 0  {'speaker': 'All', 'utterance': 'Hey!', 'emoti...
# 1  {'speaker': 'Ross', 'utterance': 'Yeah!!', 'em...
# 2  {'speaker': 'Woman', 'utterance': 'Uh, actuall...
#
#                                                   8   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Ohh, you g...
# 1  {'speaker': 'Chandler', 'utterance': 'Tonight?...
# 2  {'speaker': 'Ross', 'utterance': 'I find Mario...
#
#                                                   9   ...  \
# 0  {'speaker': 'Rachel', 'utterance': 'Where?!', ...  ...
# 1                                               None  ...
# 2  {'speaker': 'Woman', 'utterance': 'Im sorry, ...  ...
#
#                                                   14  \
# 0  {'speaker': 'Monica', 'utterance': 'Well, next...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Well I uh, I...
#
#                                                   15  \
# 0  {'speaker': 'Joey', 'utterance': 'Yeah! Yeah! ...
# 1                                               None
# 2                                               None
#
#                                                   16  \
# 0  {'speaker': 'Chandler', 'utterance': 'Thank yo...
# 1                                               None
# 2                                               None
#
#                                                   17    18    19    20    21  \
# 0  {'speaker': 'Joey', 'utterance': 'No-no, thank...  None  None  None  None
# 1                                               None  None  None  None  None
# 2                                               None  None  None  None  None
#
#      22    23
# 0  None  None
# 1  None  None
# 2  None  None
#
# [3 rows x 24 columns]

# %%
# Cell 6

print(train_df.shape)
print(test_df.shape)
print(holdout_df.shape)
# Out:
# (720, 24)
# (200, 24)
# (80, 24)

# %%
# cell 7

train_df.info()
test_df.info()
holdout_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       720 non-null    object
#  1   1       720 non-null    object
#  2   2       720 non-null    object
#  3   3       720 non-null    object
#  4   4       720 non-null    object
#  5   5       688 non-null    object
#  6   6       655 non-null    object
#  7   7       620 non-null    object
#  8   8       579 non-null    object
#  9   9       547 non-null    object
#  10  10      520 non-null    object
#  11  11      484 non-null    object
#  12  12      444 non-null    object
#  13  13      408 non-null    object
#  14  14      367 non-null    object
#  15  15      333 non-null    object
#  16  16      292 non-null    object
#  17  17      253 non-null    object
#  18  18      224 non-null    object
#  19  19      189 non-null    object
#  20  20      142 non-null    object
#  21  21      102 non-null    object
#  22  22      79 non-null     object
#  23  23      35 non-null     object
# dtypes: object(24)
# memory usage: 135.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       200 non-null    object
#  1   1       200 non-null    object
#  2   2       200 non-null    object
#  3   3       200 non-null    object
#  4   4       200 non-null    object
#  5   5       188 non-null    object
#  6   6       175 non-null    object
#  7   7       162 non-null    object
#  8   8       155 non-null    object
#  9   9       140 non-null    object
#  10  10      132 non-null    object
#  11  11      126 non-null    object
#  12  12      111 non-null    object
#  13  13      102 non-null    object
#  14  14      93 non-null     object
#  15  15      83 non-null     object
#  16  16      72 non-null     object
#  17  17      63 non-null     object
#  18  18      53 non-null     object
#  19  19      40 non-null     object
#  20  20      30 non-null     object
#  21  21      21 non-null     object
#  22  22      13 non-null     object
#  23  23      5 non-null      object
# dtypes: object(24)
# memory usage: 37.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       80 non-null     object
#  1   1       80 non-null     object
#  2   2       80 non-null     object
#  3   3       80 non-null     object
#  4   4       80 non-null     object
#  5   5       79 non-null     object
#  6   6       75 non-null     object
#  7   7       74 non-null     object
#  8   8       67 non-null     object
#  9   9       63 non-null     object
#  10  10      61 non-null     object
#  11  11      55 non-null     object
#  12  12      50 non-null     object
#  13  13      43 non-null     object
#  14  14      40 non-null     object
#  15  15      35 non-null     object
#  16  16      30 non-null     object
#  17  17      27 non-null     object
#  18  18      23 non-null     object
#  19  19      21 non-null     object
#  20  20      17 non-null     object
#  21  21      11 non-null     object
#  22  22      6 non-null      object
#  23  23      1 non-null      object
# dtypes: object(24)
# memory usage: 15.1+ KB

# %%
train_df.head(5)
# Out:
#                                                   0   \
# 0  {'speaker': 'Chandler', 'utterance': 'also I w...
# 1  {'speaker': 'Chandler', 'utterance': 'Hey, Mon...
# 2  {'speaker': 'Rachel', 'utterance': 'Hey!', 'em...
# 3  {'speaker': 'Chandler', 'utterance': 'Good job...
# 4  {'speaker': 'Joey', 'utterance': 'Okay, look, ...
#
#                                                   1   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'Y...
# 1  {'speaker': 'Monica', 'utterance': 'Hey-hey-he...
# 2  {'speaker': 'Ross', 'utterance': 'Hi!', 'emoti...
# 3  {'speaker': 'Joey', 'utterance': 'You liked it...
# 4  {'speaker': 'Ross', 'utterance': 'What?! What ...
#
#                                                   2   \
# 0  {'speaker': 'Chandler', 'utterance': 'That I d...
# 1  {'speaker': 'Chandler', 'utterance': 'Do I eve...
# 2  {'speaker': 'Rachel', 'utterance': 'What are y...
# 3  {'speaker': 'Chandler', 'utterance': 'Oh-ho-ho...
# 4  {'speaker': 'Phoebe', 'utterance': 'Yes, and i...
#
#                                                   3   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'S...
# 1  {'speaker': 'Monica', 'utterance': 'Chris says...
# 2  {'speaker': 'Ross', 'utterance': 'Ah y'know, t...
# 3  {'speaker': 'Joey', 'utterance': 'Which part e...
# 4  {'speaker': 'Phoebe', 'utterance': 'See, if I...
#
#                                                   4   \
# 0  {'speaker': 'Chandler', 'utterance': 'My dutie...
# 1  {'speaker': 'Chandler', 'utterance': 'No way!'...
# 2  {'speaker': 'Rachel', 'utterance': 'Oh.', 'emo...
# 3  {'speaker': 'Chandler', 'utterance': 'The whol...
# 4  {'speaker': 'Chandler', 'utterance': 'Okay, th...
#
#                                                   5   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'N...
# 1  {'speaker': 'Monica', 'utterance': 'Yeah, appa...
# 2  {'speaker': 'Ross', 'utterance': 'Hi.', 'emoti...
# 3  {'speaker': 'Joey', 'utterance': 'Oh no-no-no,...
# 4  {'speaker': 'Customer', 'utterance': 'I dont ...
#
#                                                   6   \
# 0  {'speaker': 'Chandler', 'utterance': 'I see.',...
# 1  {'speaker': 'Chandler', 'utterance': 'Just cof...
# 2  {'speaker': 'Rachel', 'utterance': 'Hi.', 'emo...
# 3  {'speaker': 'Chandler', 'utterance': 'I love t...
# 4  {'speaker': 'Chandler', 'utterance': 'Great! O...
#
#                                                   7   \
# 0  {'speaker': 'The Interviewer', 'utterance': 'B...
# 1  {'speaker': 'Monica', 'utterance': 'Got me.', ...
# 2  {'speaker': 'Ross', 'utterance': 'Howd did it...
# 3  {'speaker': 'Joey', 'utterance': 'Hey, what ab...
# 4  {'speaker': 'Customer', 'utterance': 'All righ...
#
#                                                   8   \
# 0  {'speaker': 'Chandler', 'utterance': 'Good to ...
# 1  {'speaker': 'Chandler', 'utterance': 'Can I ge...
# 2  {'speaker': 'Rachel', 'utterance': 'Oh well, t...
# 3  {'speaker': 'Chandler', 'utterance': 'I was su...
# 4  {'speaker': 'Chandler', 'utterance': 'Thank yo...
#
#                                                   9   ...  \
# 0  {'speaker': 'The Interviewer', 'utterance': 'W...  ...
# 1  {'speaker': 'Monica', 'utterance': 'Hey, did y...  ...
# 2  {'speaker': 'Ross', 'utterance': 'Im so proud...  ...
# 3  {'speaker': 'Joey', 'utterance': 'You fell asl...  ...
# 4                                               None  ...
#
#                                                   14  \
# 0  {'speaker': 'Joey', 'utterance': 'But then who...
# 1  {'speaker': 'Chandler', 'utterance': 'What, wh...
# 2  {'speaker': 'Rachel', 'utterance': 'Yeah.', 'e...
# 3  {'speaker': 'Chandler', 'utterance': 'Dont go...
# 4                                               None
#
#                                                   15  \
# 0  {'speaker': 'Rachel', 'utterance': 'You know? ...
# 1  {'speaker': 'Phoebe', 'utterance': 'What?!', '...
# 2  {'speaker': 'Phoebe', 'utterance': 'Ameri-can....
# 3  {'speaker': 'Chandler', 'utterance': 'Im sorr...
# 4                                               None
#
#                                                   16  \
# 0  {'speaker': 'Joey', 'utterance': 'No-no-no-no,...
# 1  {'speaker': 'Phoebe', 'utterance': 'He was wit...
# 2  {'speaker': 'Sergei', 'utterance': 'Ameri-ccan...
# 3  {'speaker': 'Chandler', 'utterance': 'Im so s...
# 4                                               None
#
#                                                   17  \
# 0  {'speaker': 'Rachel', 'utterance': 'No, I-I-I-...
# 1  {'speaker': 'Phoebe', 'utterance': 'Look,  'My...
# 2  {'speaker': 'Phoebe', 'utterance': 'Ameri-can....
# 3  {'speaker': 'Chandler', 'utterance': 'Look!', ...
# 4                                               None
#
#                                                   18  \
# 0  {'speaker': 'Joey', 'utterance': 'Ok!', 'emoti...
# 1  {'speaker': 'Phoebe', 'utterance': 'Now that I...
# 2  {'speaker': 'Sergei', 'utterance': 'Everybody!...
# 3  {'speaker': 'Chandler', 'utterance': 'This guy...
# 4                                               None
#
#                                                   19  \
# 0  {'speaker': 'Joey', 'utterance': 'All right, w...
# 1  {'speaker': 'Phoebe', 'utterance': 'He thinks ...
# 2                                               None
# 3  {'speaker': 'Chandler', 'utterance': 'He fell ...
# 4                                               None
#
#                                                   20  \
# 0  {'speaker': 'Joey', 'utterance': 'I'm gonna se...
# 1  {'speaker': 'Chandler', 'utterance': 'You real...
# 2                                               None
# 3  {'speaker': 'Chandler', 'utterance': 'Be mad a...
# 4                                               None
#
#                                                   21  \
# 0  {'speaker': 'Joey', 'utterance': 'I'll see you...
# 1  {'speaker': 'Phoebe', 'utterance': 'Oh, totall...
# 2                                               None
# 3  {'speaker': 'Chandler', 'utterance': 'Or, call...
# 4                                               None
#
#                                                   22    23
# 0  {'speaker': 'Rachel', 'utterance': 'Yeah, sure...  None
# 1  {'speaker': 'Joey', 'utterance': 'Done.', 'emo...  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
#
# [5 rows x 24 columns]

# %%
test_df.head()
# Out:
#                                                   0   \
# 0  {'speaker': 'Mark', 'utterance': 'Why do all y...
# 1  {'speaker': 'Joey', 'utterance': 'Come on, Lyd...
# 2  {'speaker': 'Ross', 'utterance': 'Okay.', 'emo...
# 3  {'speaker': 'Phoebe', 'utterance': 'Ohh!', 'em...
# 4  {'speaker': 'Joey', 'utterance': 'Previously o...
#
#                                                   1   \
# 0  {'speaker': 'Rachel', 'utterance': 'Oh. Thats...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Rachel', 'utterance': 'Ross, didn...
# 3  {'speaker': 'Monica', 'utterance': 'What?', 'e...
# 4  {'speaker': 'Monica', 'utterance': 'I dont kn...
#
#                                                   2   \
# 0  {'speaker': 'Rachel', 'utterance': 'Y'know wha...
# 1  {'speaker': 'Joey', 'utterance': 'Push 'em out...
# 2  {'speaker': 'Ross', 'utterance': 'Uhh, yes I d...
# 3  {'speaker': 'Phoebe', 'utterance': 'It kicked!...
# 4  {'speaker': 'Phoebe', 'utterance': 'Oh?!', 'em...
#
#                                                   3   \
# 0  {'speaker': 'Ross', 'utterance': 'It didnt.',...
# 1  {'speaker': 'Joey', 'utterance': 'Push 'em out...
# 2  {'speaker': 'Ross', 'utterance': 'Okay, go lef...
# 3  {'speaker': 'Monica', 'utterance': 'Oh my God!...
# 4  {'speaker': 'Monica', 'utterance': 'Yeah, but ...
#
#                                                   4   \
# 0  {'speaker': 'Frank', 'utterance': 'Okay, so wh...
# 1  {'speaker': 'Joey', 'utterance': 'Let's get th...
# 2  {'speaker': 'Rachel', 'utterance': 'Okay, y'kn...
# 3  {'speaker': 'Phoebe', 'utterance': 'Oh no wait...
# 4  {'speaker': 'Phoebe', 'utterance': 'Oh.', 'emo...
#
#                                                   5   \
# 0  {'speaker': 'Joey', 'utterance': 'Now, wh-what...
# 1  {'speaker': 'Joey', 'utterance': 'Let's  I wa...
# 2  {'speaker': 'Ross', 'utterance': 'Oh okay, lif...
# 3  {'speaker': 'Joey', 'utterance': 'Oh my God! I...
# 4  {'speaker': 'Joey', 'utterance': 'And its not...
#
#                                                   6   \
# 0  {'speaker': 'Frank', 'utterance': 'Its so coo...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'Straight up ...
# 3  {'speaker': 'Monica', 'utterance': 'Oh wait, J...
# 4  {'speaker': 'Chandler', 'utterance': 'Yeah, it...
#
#                                                   7   \
# 0  {'speaker': 'Ross', 'utterance': 'Yeah, yeah.'...
# 1  {'speaker': 'Joey', 'utterance': 'Push!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'You can do i...
# 3  {'speaker': 'Joey', 'utterance': 'Look, I know...
# 4  {'speaker': 'Monica', 'utterance': 'So you can...
#
#                                                   8   \
# 0  {'speaker': 'Joey', 'utterance': 'Why cant I ...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'You can do i...
# 3  {'speaker': 'Joey', 'utterance': 'Theyre just...
# 4  {'speaker': 'Ross', 'utterance': 'Yeah, anythi...
#
#                                                   9   ...  \
# 0  {'speaker': 'Ross', 'utterance': 'Dont ask me...  ...
# 1                                               None  ...
# 2  {'speaker': 'Ross', 'utterance': 'Okay.', 'emo...  ...
# 3  {'speaker': 'Chandler', 'utterance': 'Youre c...  ...
# 4  {'speaker': 'Monica', 'utterance': 'Whats fis...  ...
#
#                                                   14  \
# 0  {'speaker': 'Frank', 'utterance': 'Its out th...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Yes but too ...
# 3  {'speaker': 'Chandler', 'utterance': 'So uh, w...
# 4                                               None
#
#                                                   15  \
# 0  {'speaker': 'Joey', 'utterance': 'Then you hol...
# 1                                               None
# 2  {'speaker': 'Steve', 'utterance': 'Okay, fine,...
# 3  {'speaker': 'Marjorie', 'utterance': 'I talk i...
# 4                                               None
#
#                                                   16  \
# 0  {'speaker': 'Frank', 'utterance': 'All right, ...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Ugh, can you...
# 3  {'speaker': 'Chandler', 'utterance': 'What a c...
# 4                                               None
#
#                                                   17    18    19    20    21  \
# 0  {'speaker': 'Joey', 'utterance': 'All right, c...  None  None  None  None
# 1                                               None  None  None  None  None
# 2  {'speaker': 'Phoebe', 'utterance': 'Yeah. I re...  None  None  None  None
# 3  {'speaker': 'Joey', 'utterance': 'So why dont...  None  None  None  None
# 4                                               None  None  None  None  None
#
#      22    23
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 24 columns]

# %%
holdout_df.head()
# Out:
#                                                   0   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Oh my God,...
# 1  {'speaker': 'Joey', 'utterance': 'Hey Estelle,...
# 2  {'speaker': 'Ross', 'utterance': 'Yes? Yes?! H...
# 3  {'speaker': 'Ross', 'utterance': 'You had no r...
# 4  {'speaker': 'Phoebe', 'utterance': 'Oh, it's s...
#
#                                                   1   \
# 0  {'speaker': 'Monica', 'utterance': 'What?', 'e...
# 1  {'speaker': 'Estelle', 'utterance': 'Well! Wel...
# 2  {'speaker': 'Guy', 'utterance': 'Yeah, we were...
# 3  {'speaker': 'Rachel', 'utterance': 'What?', 'e...
# 4  {'speaker': 'Joey', 'utterance': 'Yknow, Moni...
#
#                                                   2   \
# 0  {'speaker': 'Ross', 'utterance': 'Or! Or, we c...
# 1  {'speaker': 'Joey', 'utterance': 'What are you...
# 2  {'speaker': 'Ross', 'utterance': 'Oh-oh, your...
# 3  {'speaker': 'Ross', 'utterance': 'I was doing ...
# 4  {'speaker': 'Phoebe', 'utterance': 'All in goo...
#
#                                                   3   \
# 0  {'speaker': 'Chandler', 'utterance': 'Youre a...
# 1  {'speaker': 'Estelle', 'utterance': 'Really?!'...
# 2  {'speaker': 'Ross', 'utterance': 'What exactly...
# 3  {'speaker': 'Rachel', 'utterance': 'Hey, I was...
# 4  {'speaker': 'Phoebe', 'utterance': 'All in goo...
#
#                                                   4   \
# 0  {'speaker': 'Joey', 'utterance': 'Aww, man, no...
# 1  {'speaker': 'Joey', 'utterance': 'Yeah!', 'emo...
# 2  {'speaker': 'Ross', 'utterance': 'Perhaps,  pe...
# 3  {'speaker': 'Ross', 'utterance': 'The point is...
# 4  {'speaker': 'Phoebe', 'utterance': 'Oh shoot!'...
#
#                                                   5   \
# 0  {'speaker': 'Chandler', 'utterance': 'Now, the...
# 1  {'speaker': 'Estelle', 'utterance': 'Oh well, ...
# 2  {'speaker': 'Guy', 'utterance': 'Uhh
# .', 'emot...
# 3  {'speaker': 'Ross', 'utterance': 'I don't need...
# 4  {'speaker': 'Phoebe', 'utterance': 'I left my ...
#
#                                                   6   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Hey.', 'em...
# 1  {'speaker': 'Gary', 'utterance': 'Okay, you gu...
# 2  {'speaker': 'Ross', 'utterance': 'Ah
#  Ah
# Get o...
# 3  {'speaker': 'Ross', 'utterance': 'It, it's too...
# 4  {'speaker': 'Phoebe', 'utterance': 'Well you c...
#
#                                                   7   \
# 0  {'speaker': 'All', 'utterance': 'Hey!', 'emoti...
# 1  {'speaker': 'Ross', 'utterance': 'Yeah!!', 'em...
# 2  {'speaker': 'Woman', 'utterance': 'Uh, actuall...
# 3  {'speaker': 'Ross', 'utterance': 'This ship ha...
# 4  {'speaker': 'Joey', 'utterance': 'I dont have...
#
#                                                   8   \
# 0  {'speaker': 'Phoebe', 'utterance': 'Ohh, you g...
# 1  {'speaker': 'Chandler', 'utterance': 'Tonight?...
# 2  {'speaker': 'Ross', 'utterance': 'I find Mario...
# 3  {'speaker': 'Rachel', 'utterance': 'Alright, f...
# 4  {'speaker': 'Phoebe', 'utterance': 'What?! The...
#
#                                                   9   ...  \
# 0  {'speaker': 'Rachel', 'utterance': 'Where?!', ...  ...
# 1                                               None  ...
# 2  {'speaker': 'Woman', 'utterance': 'Im sorry, ...  ...
# 3  {'speaker': 'Ross', 'utterance': 'Fine.', 'emo...  ...
# 4  {'speaker': 'Joey', 'utterance': 'Why would th...  ...
#
#                                                   14  \
# 0  {'speaker': 'Monica', 'utterance': 'Well, next...
# 1                                               None
# 2  {'speaker': 'Ross', 'utterance': 'Well I uh, I...
# 3                                               None
# 4  {'speaker': 'Ross', 'utterance': 'Uh, what?', ...
#
#                                                   15  \
# 0  {'speaker': 'Joey', 'utterance': 'Yeah! Yeah! ...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'speaker': 'Rachel', 'utterance': 'Yes! Shes...
#
#                                                   16  \
# 0  {'speaker': 'Chandler', 'utterance': 'Thank yo...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'speaker': 'Ross', 'utterance': 'WhatYoure ...
#
#                                                   17  \
# 0  {'speaker': 'Joey', 'utterance': 'No-no, thank...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'speaker': 'Ross', 'utterance': 'I mean shes...
#
#                                                   18  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'speaker': 'Ross', 'utterance': 'Shell drive...
#
#                                                   19  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'speaker': 'Mrs. Green', 'utterance': 'Hi Ros...
#
#                                                   20    21    22    23
# 0                                               None  None  None  None
# 1                                               None  None  None  None
# 2                                               None  None  None  None
# 3                                               None  None  None  None
# 4  {'speaker': 'Ross', 'utterance': 'Hi roomie!',...  None  None  None
#
# [5 rows x 24 columns]

# %%
# Cell 9

train_df_backup = train_df.copy()
test_df_backup = test_df.copy()
holdout_df_backup = holdout_df.copy()

# %% [markdown]
# ## **Step 2 - Conduct Text Preprocessing**

# %% [markdown]
# ### **Tokenization**

# %%
# Cell 10

# Updated Tokenization Function
def tokenize_utterances(cell, key='utterance'):
    # Check if the cell is a dictionary and has the specified key
    if isinstance(cell, dict) and key in cell:
        return word_tokenize(cell[key])
    else:
        return []
# Columns that contain JSON objects with utterances
json_columns = list(range(24))  # Adjust this list based on your DataFrame (0 to 23)

# Apply tokenization to each JSON column
for col in json_columns:
    col_name = f'tokenized_{col}'
    train_df[col_name] = train_df[col].apply(lambda x: tokenize_utterances(x, key='utterance'))

# Display the results for verification
print("Modified Training DataFrame:")
print(train_df[[f'tokenized_{col}' for col in json_columns]].head())
# Out:
# Modified Training DataFrame:
#                                          tokenized_0  \
# 0  [also, I, was, the, point, person, on, my, com...
# 1                                   [Hey, ,, Mon, .]
# 2                                           [Hey, !]
# 3  [Good, job, Joe, !, Well, done, !, Top, notch, !]
# 4  [Okay, ,, look, ,, I, think, we, have, to, tel...
#
#                                          tokenized_1  \
# 0          [You, mustve, had, your, hands, full, .]
# 1  [Hey-hey-hey, ., You, wan, na, hear, something...
# 2                                            [Hi, !]
# 3     [You, liked, it, ?, You, really, liked, it, ?]
# 4  [What, ?, !, What, is, with, everybody, ?, It...
#
#                                          tokenized_2  \
# 0                 [That, I, did, ., That, I, did, .]
# 1                                   [Do, I, ever, .]
# 2                   [What, are, you, doing, here, ?]
# 3                             [Oh-ho-ho, ,, yeah, !]
# 4  [Yes, ,, and, it, is, my, dying, wish, to, hav...
#
#                                          tokenized_3  \
# 0  [So, lets, talk, a, little, bit, about, your,...
# 1  [Chris, says, theyre, closing, down, the, bar...
# 2  [Ah, y'know, ,, this, building, is, on, my, pa...
# 3                          [Which, part, exactly, ?]
# 4  [See, ,, if, Im, not, buried, with, that, rin...
#
#                               tokenized_4  \
# 0          [My, duties, ?, All, right, .]
# 1                            [No, way, !]
# 2                                 [Oh, .]
# 3  [The, whole, thing, !, Can, we, go, ?]
# 4     [Okay, ,, thats, enough, honey, !]
#
#                                          tokenized_5  \
# 0  [Now, youll, be, heading, a, whole, division,...
# 1  [Yeah, ,, apparently, theyre, turning, it, in...
# 2                                            [Hi, .]
# 3    [Oh, no-no-no, ,, give, me, some, specifics, .]
# 4    [I, dont, know, ., Let, me, see, the, ring, .]
#
#                                          tokenized_6  \
# 0                                        [I, see, .]
# 1  [Just, coffee, !, Where, are, we, gon, na, han...
# 2                                            [Hi, .]
# 3  [I, love, the, specifics, ,, the, specifics, w...
# 4                       [Great, !, Okay, ,, here, .]
#
#                                          tokenized_7  \
# 0  [But, therell, be, perhaps, 30, people, under...
# 1                                       [Got, me, .]
# 2                            [Howd, did, it, go, ?]
# 3  [Hey, ,, what, about, the, scene, with, the, k...
# 4                                    [All, right, .]
#
#                                          tokenized_8  \
# 0                                [Good, to, know, .]
# 1                          [Can, I, get, a, beer, .]
# 2  [Oh, well, ,, the, woman, I, interviewed, with...
# 3  [I, was, surprised, to, see, a, kangaroo, in, ...
# 4  [Thank, you, ., Thank, you, ., Thank, you, !, ...
#
#                                 tokenized_9  ...  \
# 0               [We, can, go, into, detail]  ...
# 1  [Hey, ,, did, you, pick, a, roommate, ?]  ...
# 2              [Im, so, proud, of, you, .]  ...
# 3                 [You, fell, asleep, !, !]  ...
# 4                                        []  ...
#
#                                         tokenized_14  \
# 0  [But, then, who, ?, The, waitress, I, went, ou...
# 1                     [What, ,, what, ,, what, ?, !]
# 2                                          [Yeah, .]
# 3                                     [Dont, go, !]
# 4                                                 []
#
#                     tokenized_15  \
# 0  [You, know, ?, Forget, it, !]
# 1                   [What, ?, !]
# 2                 [Ameri-can, .]
# 3                [Im, sorry, .]
# 4                             []
#
#                                         tokenized_16  \
# 0  [No-no-no-no, ,, no, !, Who, ,, who, were, you...
# 1  [He, was, with, her, when, he, wrote, this, po...
# 2                                    [Ameri-ccan, .]
# 3                                [Im, so, sorry, !]
# 4                                                 []
#
#                                         tokenized_17  \
# 0  [No, ,, I-I-I-I, do, n't, ,, I, actually, do, ...
# 1  [Look, ,, 'My, vessel, so, empty, with, nothin...
# 2                    [Ameri-can, ., Y'know, its, a]
# 3                                          [Look, !]
# 4                                                 []
#
#                                         tokenized_18  \
# 0                                            [Ok, !]
# 1  [Now, that, I, 've, touched, you, ,, you, seem...
# 2                                  [Everybody, !, !]
# 3                       [This, guy, fell, asleep, !]
# 4                                                 []
#
#                                         tokenized_19  \
# 0                         [All, right, ,, well, ...]
# 1  [He, thinks, Monica, is, empty, ,, she, is, th...
# 2                                                 []
# 3                         [He, fell, asleep, too, !]
# 4                                                 []
#
#                                         tokenized_20  \
# 0  [I, 'm, gon, na, see, if, I, can, get, a, room...
# 1  [You, really, think, that, is, what, he, meant...
# 2                                                 []
# 3                              [Be, mad, at, him, !]
# 4                                                 []
#
#                                         tokenized_21        tokenized_22  \
# 0                       [I, 'll, see, you, later, !]  [Yeah, ,, sure, !]
# 1  [Oh, ,, totally, ., Oh, ,, God, ,, oh, ,, she,...           [Done, .]
# 2                                                 []                  []
# 3                    [Or, ,, call, an, ambulance, .]                  []
# 4                                                 []                  []
#
#   tokenized_23
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
#
# [5 rows x 24 columns]

# %% [markdown]
# ### **Removing Stopwords**

# %%
# Cell 11

# Load English stopwords
stop_words = set(stopwords.words('english'))
# Updated Stopword Removal Function
# def remove_stopwords(tokens, stop_words):
#     return [token for token in tokens if token not in stop_words]

def remove_stopwords(tokens, *args):
    stop_words = args[0] if args else set()
    return [token for token in tokens if token not in stop_words]

# Ensure all column names are strings
train_df.columns = train_df.columns.astype(str)

# Columns that contain tokenized utterances
tokenized_columns = [col for col in train_df.columns if str(col).startswith('tokenized')]

# Apply the function to remove stop words from each tokenized column
for col in tokenized_columns:
    train_df[col] = train_df[col].apply(lambda x: remove_stopwords(x, stop_words))

# Display the results for verification
print("DataFrame with Stop Words Removed:")
print(train_df[tokenized_columns].head())
# Out:
# DataFrame with Stop Words Removed:
#                                          tokenized_0  \
# 0  [also, I, point, person, companys, transition...
# 1                                   [Hey, ,, Mon, .]
# 2                                           [Hey, !]
# 3  [Good, job, Joe, !, Well, done, !, Top, notch, !]
# 4  [Okay, ,, look, ,, I, think, tell, Rachel, mes...
#
#                                          tokenized_1  \
# 0                     [You, mustve, hands, full, .]
# 1  [Hey-hey-hey, ., You, wan, na, hear, something...
# 2                                            [Hi, !]
# 3             [You, liked, ?, You, really, liked, ?]
# 4  [What, ?, !, What, everybody, ?, Its, Thanksg...
#
#                       tokenized_2  \
# 0        [That, I, ., That, I, .]
# 1                [Do, I, ever, .]
# 2                       [What, ?]
# 3          [Oh-ho-ho, ,, yeah, !]
# 4  [Yes, ,, dying, wish, ring, .]
#
#                                          tokenized_3  \
# 0          [So, lets, talk, little, bit, duties, .]
# 1            [Chris, says, theyre, closing, bar, .]
# 2    [Ah, y'know, ,, building, paper, route, I, ...]
# 3                          [Which, part, exactly, ?]
# 4  [See, ,, Im, buried, ring, spirit, going, wan...
#
#                            tokenized_4  \
# 0       [My, duties, ?, All, right, .]
# 1                         [No, way, !]
# 2                              [Oh, .]
# 3   [The, whole, thing, !, Can, go, ?]
# 4  [Okay, ,, thats, enough, honey, !]
#
#                                          tokenized_5  \
# 0  [Now, youll, heading, whole, division, ,, you...
# 1  [Yeah, ,, apparently, theyre, turning, kinda,...
# 2                                            [Hi, .]
# 3              [Oh, no-no-no, ,, give, specifics, .]
# 4             [I, dont, know, ., Let, see, ring, .]
#
#                                          tokenized_6  \
# 0                                        [I, see, .]
# 1         [Just, coffee, !, Where, gon, na, hang, ?]
# 2                                            [Hi, .]
# 3  [I, love, specifics, ,, specifics, best, part, !]
# 4                             [Great, !, Okay, ,, .]
#
#                                          tokenized_7  \
# 0  [But, therell, perhaps, 30, people, dump, cer...
# 1                                           [Got, .]
# 2                                     [Howd, go, ?]
# 3  [Hey, ,, scene, kangaroo, ?, Did-did, like, pa...
# 4                                    [All, right, .]
#
#                                          tokenized_8  \
# 0                                    [Good, know, .]
# 1                             [Can, I, get, beer, .]
# 2  [Oh, well, ,, woman, I, interviewed, pretty, t...
# 3  [I, surprised, see, kangaroo, World, War, I, e...
# 4                [Thank, ., Thank, ., Thank, !, And]
#
#                    tokenized_9  ...  \
# 0             [We, go, detail]  ...
# 1  [Hey, ,, pick, roommate, ?]  ...
# 2              [Im, proud, .]  ...
# 3    [You, fell, asleep, !, !]  ...
# 4                           []  ...
#
#                                        tokenized_14  \
# 0  [But, ?, The, waitress, I, went, last, month, ?]
# 1                                [What, ,, ,, ?, !]
# 2                                         [Yeah, .]
# 3                                    [Dont, go, !]
# 4                                                []
#
#                 tokenized_15                             tokenized_16  \
# 0  [You, know, ?, Forget, !]  [No-no-no-no, ,, !, Who, ,, talking, ?]
# 1               [What, ?, !]                     [He, wrote, poem, .]
# 2             [Ameri-can, .]                          [Ameri-ccan, .]
# 3            [Im, sorry, .]                          [Im, sorry, !]
# 4                         []                                       []
#
#                                         tokenized_17  \
# 0   [No, ,, I-I-I-I, n't, ,, I, actually, n't, know]
# 1  [Look, ,, 'My, vessel, empty, nothing, inside, .]
# 2                       [Ameri-can, ., Y'know, its]
# 3                                          [Look, !]
# 4                                                 []
#
#                                         tokenized_18  \
# 0                                            [Ok, !]
# 1  [Now, I, 've, touched, ,, seem, emptier, still...
# 2                                  [Everybody, !, !]
# 3                       [This, guy, fell, asleep, !]
# 4                                                 []
#
#                                      tokenized_19  \
# 0                      [All, right, ,, well, ...]
# 1  [He, thinks, Monica, empty, ,, empty, vase, !]
# 2                                              []
# 3                           [He, fell, asleep, !]
# 4                                              []
#
#                                         tokenized_20  \
# 0  [I, 'm, gon, na, see, I, get, room, night, I, ...
# 1                     [You, really, think, meant, ?]
# 2                                                 []
# 3                                       [Be, mad, !]
# 4                                                 []
#
#                                         tokenized_21        tokenized_22  \
# 0                            [I, 'll, see, later, !]  [Yeah, ,, sure, !]
# 1  [Oh, ,, totally, ., Oh, ,, God, ,, oh, ,, seem...           [Done, .]
# 2                                                 []                  []
# 3                        [Or, ,, call, ambulance, .]                  []
# 4                                                 []                  []
#
#   tokenized_23
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
#
# [5 rows x 24 columns]

# %% [markdown]
# ### **Lemmatization**

# %%
# Cell 12

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Updated Lemmatization Function
def lemmatize_tokens(tokens, lemmatizer):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Columns that contain tokenized and stop words-removed text
lemmatized_columns = [col for col in train_df.columns if col.startswith('tokenized')]

# Apply the function to perform lemmatization on each column
for col in lemmatized_columns:
    train_df[col] = train_df[col].apply(lambda x: lemmatize_tokens(x, lemmatizer))

# Display the results for verification
print("DataFrame after Lemmatization:")
print(train_df[lemmatized_columns].head())
# Out:
# DataFrame after Lemmatization:
#                                          tokenized_0  \
# 0  [also, I, point, person, companys, transition...
# 1                                   [Hey, ,, Mon, .]
# 2                                           [Hey, !]
# 3  [Good, job, Joe, !, Well, done, !, Top, notch, !]
# 4  [Okay, ,, look, ,, I, think, tell, Rachel, mes...
#
#                                          tokenized_1  \
# 0                      [You, mustve, hand, full, .]
# 1  [Hey-hey-hey, ., You, wan, na, hear, something...
# 2                                            [Hi, !]
# 3             [You, liked, ?, You, really, liked, ?]
# 4  [What, ?, !, What, everybody, ?, Its, Thanksg...
#
#                       tokenized_2  \
# 0        [That, I, ., That, I, .]
# 1                [Do, I, ever, .]
# 2                       [What, ?]
# 3          [Oh-ho-ho, ,, yeah, !]
# 4  [Yes, ,, dying, wish, ring, .]
#
#                                          tokenized_3  \
# 0            [So, lets, talk, little, bit, duty, .]
# 1             [Chris, say, theyre, closing, bar, .]
# 2    [Ah, y'know, ,, building, paper, route, I, ...]
# 3                          [Which, part, exactly, ?]
# 4  [See, ,, Im, buried, ring, spirit, going, wan...
#
#                            tokenized_4  \
# 0         [My, duty, ?, All, right, .]
# 1                         [No, way, !]
# 2                              [Oh, .]
# 3   [The, whole, thing, !, Can, go, ?]
# 4  [Okay, ,, thats, enough, honey, !]
#
#                                          tokenized_5  \
# 0  [Now, youll, heading, whole, division, ,, you...
# 1  [Yeah, ,, apparently, theyre, turning, kinda,...
# 2                                            [Hi, .]
# 3               [Oh, no-no-no, ,, give, specific, .]
# 4             [I, dont, know, ., Let, see, ring, .]
#
#                                        tokenized_6  \
# 0                                      [I, see, .]
# 1       [Just, coffee, !, Where, gon, na, hang, ?]
# 2                                          [Hi, .]
# 3  [I, love, specific, ,, specific, best, part, !]
# 4                           [Great, !, Okay, ,, .]
#
#                                          tokenized_7  \
# 0  [But, therell, perhaps, 30, people, dump, cer...
# 1                                           [Got, .]
# 2                                     [Howd, go, ?]
# 3  [Hey, ,, scene, kangaroo, ?, Did-did, like, pa...
# 4                                    [All, right, .]
#
#                                          tokenized_8  \
# 0                                    [Good, know, .]
# 1                             [Can, I, get, beer, .]
# 2  [Oh, well, ,, woman, I, interviewed, pretty, t...
# 3  [I, surprised, see, kangaroo, World, War, I, e...
# 4                [Thank, ., Thank, ., Thank, !, And]
#
#                    tokenized_9  ...  \
# 0             [We, go, detail]  ...
# 1  [Hey, ,, pick, roommate, ?]  ...
# 2              [Im, proud, .]  ...
# 3    [You, fell, asleep, !, !]  ...
# 4                           []  ...
#
#                                        tokenized_14  \
# 0  [But, ?, The, waitress, I, went, last, month, ?]
# 1                                [What, ,, ,, ?, !]
# 2                                         [Yeah, .]
# 3                                    [Dont, go, !]
# 4                                                []
#
#                 tokenized_15                             tokenized_16  \
# 0  [You, know, ?, Forget, !]  [No-no-no-no, ,, !, Who, ,, talking, ?]
# 1               [What, ?, !]                     [He, wrote, poem, .]
# 2             [Ameri-can, .]                          [Ameri-ccan, .]
# 3            [Im, sorry, .]                          [Im, sorry, !]
# 4                         []                                       []
#
#                                         tokenized_17  \
# 0   [No, ,, I-I-I-I, n't, ,, I, actually, n't, know]
# 1  [Look, ,, 'My, vessel, empty, nothing, inside, .]
# 2                       [Ameri-can, ., Y'know, its]
# 3                                          [Look, !]
# 4                                                 []
#
#                                         tokenized_18  \
# 0                                            [Ok, !]
# 1  [Now, I, 've, touched, ,, seem, emptier, still...
# 2                                  [Everybody, !, !]
# 3                       [This, guy, fell, asleep, !]
# 4                                                 []
#
#                                     tokenized_19  \
# 0                     [All, right, ,, well, ...]
# 1  [He, think, Monica, empty, ,, empty, vase, !]
# 2                                             []
# 3                          [He, fell, asleep, !]
# 4                                             []
#
#                                         tokenized_20  \
# 0  [I, 'm, gon, na, see, I, get, room, night, I, ...
# 1                     [You, really, think, meant, ?]
# 2                                                 []
# 3                                       [Be, mad, !]
# 4                                                 []
#
#                                         tokenized_21        tokenized_22  \
# 0                            [I, 'll, see, later, !]  [Yeah, ,, sure, !]
# 1  [Oh, ,, totally, ., Oh, ,, God, ,, oh, ,, seem...           [Done, .]
# 2                                                 []                  []
# 3                        [Or, ,, call, ambulance, .]                  []
# 4                                                 []                  []
#
#   tokenized_23
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
#
# [5 rows x 24 columns]

# %% [markdown]
# ### **Remove Punctuation and Lowercasing**

# %%
# Cell 13

# Updated Punctuation Removal and Lowercasing Function
def remove_punctuation_and_lower(tokens, lowercase=True):
    tokens = [token for token in tokens if token not in string.punctuation]
    return [token.lower() for token in tokens] if lowercase else tokens

# Columns that contain lemmatized text
processed_columns = [col for col in train_df.columns if col.startswith('tokenized')]

# Apply the function to remove punctuation and convert to lower case
for col in processed_columns:
    train_df[col] = train_df[col].apply(lambda x: remove_punctuation_and_lower(x, lowercase=True))

# Display the results for verification
print("DataFrame after Removing Punctuation and Lowercasing:")
print(train_df[processed_columns].head())
# Out:
# DataFrame after Removing Punctuation and Lowercasing:
#                                          tokenized_0  \
# 0  [also, i, point, person, companys, transition...
# 1                                         [hey, mon]
# 2                                              [hey]
# 3           [good, job, joe, well, done, top, notch]
# 4  [okay, look, i, think, tell, rachel, messed, d...
#
#                                          tokenized_1  \
# 0                         [you, mustve, hand, full]
# 1  [hey-hey-hey, you, wan, na, hear, something, s...
# 2                                               [hi]
# 3                   [you, liked, you, really, liked]
# 4  [what, what, everybody, its, thanksgiving, .....
#
#                 tokenized_2  \
# 0        [that, i, that, i]
# 1             [do, i, ever]
# 2                    [what]
# 3          [oh-ho-ho, yeah]
# 4  [yes, dying, wish, ring]
#
#                                          tokenized_3  \
# 0               [so, lets, talk, little, bit, duty]
# 1                [chris, say, theyre, closing, bar]
# 2       [ah, y'know, building, paper, route, i, ...]
# 3                             [which, part, exactly]
# 4  [see, im, buried, ring, spirit, going, wander...
#
#                      tokenized_4  \
# 0         [my, duty, all, right]
# 1                      [no, way]
# 2                           [oh]
# 3   [the, whole, thing, can, go]
# 4  [okay, thats, enough, honey]
#
#                                          tokenized_5  \
# 0  [now, youll, heading, whole, division, youll...
# 1  [yeah, apparently, theyre, turning, kinda, co...
# 2                                               [hi]
# 3                     [oh, no-no-no, give, specific]
# 4                   [i, dont, know, let, see, ring]
#
#                                  tokenized_6  \
# 0                                   [i, see]
# 1       [just, coffee, where, gon, na, hang]
# 2                                       [hi]
# 3  [i, love, specific, specific, best, part]
# 4                              [great, okay]
#
#                                          tokenized_7  \
# 0  [but, therell, perhaps, 30, people, dump, cer...
# 1                                              [got]
# 2                                        [howd, go]
# 3        [hey, scene, kangaroo, did-did, like, part]
# 4                                       [all, right]
#
#                                          tokenized_8            tokenized_9  \
# 0                                       [good, know]       [we, go, detail]
# 1                                [can, i, get, beer]  [hey, pick, roommate]
# 2  [oh, well, woman, i, interviewed, pretty, toug...           [im, proud]
# 3  [i, surprised, see, kangaroo, world, war, i, e...    [you, fell, asleep]
# 4                         [thank, thank, thank, and]                     []
#
#    ...                                tokenized_14         tokenized_15  \
# 0  ...  [but, the, waitress, i, went, last, month]  [you, know, forget]
# 1  ...                                      [what]               [what]
# 2  ...                                      [yeah]          [ameri-can]
# 3  ...                                 [dont, go]         [im, sorry]
# 4  ...                                          []                   []
#
#                   tokenized_16                                 tokenized_17  \
# 0  [no-no-no-no, who, talking]   [no, i-i-i-i, n't, i, actually, n't, know]
# 1            [he, wrote, poem]  [look, 'my, vessel, empty, nothing, inside]
# 2                 [ameri-ccan]                    [ameri-can, y'know, its]
# 3                 [im, sorry]                                       [look]
# 4                           []                                           []
#
#                                    tokenized_18  \
# 0                                          [ok]
# 1  [now, i, 've, touched, seem, emptier, still]
# 2                                   [everybody]
# 3                     [this, guy, fell, asleep]
# 4                                            []
#
#                               tokenized_19  \
# 0                  [all, right, well, ...]
# 1  [he, think, monica, empty, empty, vase]
# 2                                       []
# 3                       [he, fell, asleep]
# 4                                       []
#
#                                         tokenized_20  \
# 0  [i, 'm, gon, na, see, i, get, room, night, i, ...
# 1                        [you, really, think, meant]
# 2                                                 []
# 3                                          [be, mad]
# 4                                                 []
#
#                                 tokenized_21  tokenized_22 tokenized_23
# 0                       [i, 'll, see, later]  [yeah, sure]           []
# 1  [oh, totally, oh, god, oh, seemed, happy]        [done]           []
# 2                                         []            []           []
# 3                      [or, call, ambulance]            []           []
# 4                                         []            []           []
#
# [5 rows x 24 columns]

# %% [markdown]
# ### **Verifying text preprocessing**

# %%
# Cell 14

# Verify Tokenization
for col in json_columns:
    col_name = f'tokenized_{col}'
    print(f"Tokenized {col_name}:\n{train_df[col_name].head()}")

# Verify Stopword Removal
for col in tokenized_columns:
    print(f"After Stopword Removal {col}:\n{train_df[col].head()}")

# Verify Lemmatization
for col in lemmatized_columns:
    print(f"After Lemmatization {col}:\n{train_df[col].head()}")

# Verify Punctuation Removal and Lowercasing
for col in processed_columns:
    print(f"After Punctuation Removal and Lowercasing {col}:\n{train_df[col].head()}")
# Out:
# Tokenized tokenized_0:
# 0    [also, i, point, person, companys, transition...
# 1                                           [hey, mon]
# 2                                                [hey]
# 3             [good, job, joe, well, done, top, notch]
# 4    [okay, look, i, think, tell, rachel, messed, d...
# Name: tokenized_0, dtype: object
# Tokenized tokenized_1:
# 0                           [you, mustve, hand, full]
# 1    [hey-hey-hey, you, wan, na, hear, something, s...
# 2                                                 [hi]
# 3                     [you, liked, you, really, liked]
# 4    [what, what, everybody, its, thanksgiving, .....
# Name: tokenized_1, dtype: object
# Tokenized tokenized_2:
# 0          [that, i, that, i]
# 1               [do, i, ever]
# 2                      [what]
# 3            [oh-ho-ho, yeah]
# 4    [yes, dying, wish, ring]
# Name: tokenized_2, dtype: object
# Tokenized tokenized_3:
# 0                 [so, lets, talk, little, bit, duty]
# 1                  [chris, say, theyre, closing, bar]
# 2         [ah, y'know, building, paper, route, i, ...]
# 3                               [which, part, exactly]
# 4    [see, im, buried, ring, spirit, going, wander...
# Name: tokenized_3, dtype: object
# Tokenized tokenized_4:
# 0           [my, duty, all, right]
# 1                        [no, way]
# 2                             [oh]
# 3     [the, whole, thing, can, go]
# 4    [okay, thats, enough, honey]
# Name: tokenized_4, dtype: object
# Tokenized tokenized_5:
# 0    [now, youll, heading, whole, division, youll...
# 1    [yeah, apparently, theyre, turning, kinda, co...
# 2                                                 [hi]
# 3                       [oh, no-no-no, give, specific]
# 4                     [i, dont, know, let, see, ring]
# Name: tokenized_5, dtype: object
# Tokenized tokenized_6:
# 0                                     [i, see]
# 1         [just, coffee, where, gon, na, hang]
# 2                                         [hi]
# 3    [i, love, specific, specific, best, part]
# 4                                [great, okay]
# Name: tokenized_6, dtype: object
# Tokenized tokenized_7:
# 0    [but, therell, perhaps, 30, people, dump, cer...
# 1                                                [got]
# 2                                          [howd, go]
# 3          [hey, scene, kangaroo, did-did, like, part]
# 4                                         [all, right]
# Name: tokenized_7, dtype: object
# Tokenized tokenized_8:
# 0                                         [good, know]
# 1                                  [can, i, get, beer]
# 2    [oh, well, woman, i, interviewed, pretty, toug...
# 3    [i, surprised, see, kangaroo, world, war, i, e...
# 4                           [thank, thank, thank, and]
# Name: tokenized_8, dtype: object
# Tokenized tokenized_9:
# 0         [we, go, detail]
# 1    [hey, pick, roommate]
# 2             [im, proud]
# 3      [you, fell, asleep]
# 4                       []
# Name: tokenized_9, dtype: object
# Tokenized tokenized_10:
# 0    [no, dont, i, beg]
# 1          [you, betcha]
# 2                   [me]
# 3      [there, kangaroo]
# 4                     []
# Name: tokenized_10, dtype: object
# Tokenized tokenized_11:
# 0    [all, right, well, definite, answer, monday, ...
# 1                                   [is, italian, guy]
# 2    [listen, im, ah, im, sorry, ive, crazy, jea...
# 3                     [they, didnt, take, suggestion]
# 4                                                   []
# Name: tokenized_11, dtype: object
# Tokenized tokenized_12:
# 0                   [really]
# 1       [um-mm, yeah, right]
# 2                  [i, know]
# 3    [thats, coming, buddy]
# 4                         []
# Name: tokenized_12, dtype: object
# Tokenized tokenized_13:
# 0     [absolutely, you, relax, great]
# 1    [oh, god, oh, god, poor, monica]
# 2                              [yeah]
# 3                  [ill, see, later]
# 4                                  []
# Name: tokenized_13, dtype: object
# Tokenized tokenized_14:
# 0    [but, the, waitress, i, went, last, month]
# 1                                        [what]
# 2                                        [yeah]
# 3                                   [dont, go]
# 4                                            []
# Name: tokenized_14, dtype: object
# Tokenized tokenized_15:
# 0    [you, know, forget]
# 1                 [what]
# 2            [ameri-can]
# 3           [im, sorry]
# 4                     []
# Name: tokenized_15, dtype: object
# Tokenized tokenized_16:
# 0    [no-no-no-no, who, talking]
# 1              [he, wrote, poem]
# 2                   [ameri-ccan]
# 3                   [im, sorry]
# 4                             []
# Name: tokenized_16, dtype: object
# Tokenized tokenized_17:
# 0     [no, i-i-i-i, n't, i, actually, n't, know]
# 1    [look, 'my, vessel, empty, nothing, inside]
# 2                      [ameri-can, y'know, its]
# 3                                         [look]
# 4                                             []
# Name: tokenized_17, dtype: object
# Tokenized tokenized_18:
# 0                                            [ok]
# 1    [now, i, 've, touched, seem, emptier, still]
# 2                                     [everybody]
# 3                       [this, guy, fell, asleep]
# 4                                              []
# Name: tokenized_18, dtype: object
# Tokenized tokenized_19:
# 0                    [all, right, well, ...]
# 1    [he, think, monica, empty, empty, vase]
# 2                                         []
# 3                         [he, fell, asleep]
# 4                                         []
# Name: tokenized_19, dtype: object
# Tokenized tokenized_20:
# 0    [i, 'm, gon, na, see, i, get, room, night, i, ...
# 1                          [you, really, think, meant]
# 2                                                   []
# 3                                            [be, mad]
# 4                                                   []
# Name: tokenized_20, dtype: object
# Tokenized tokenized_21:
# 0                         [i, 'll, see, later]
# 1    [oh, totally, oh, god, oh, seemed, happy]
# 2                                           []
# 3                        [or, call, ambulance]
# 4                                           []
# Name: tokenized_21, dtype: object
# Tokenized tokenized_22:
# 0    [yeah, sure]
# 1          [done]
# 2              []
# 3              []
# 4              []
# Name: tokenized_22, dtype: object
# Tokenized tokenized_23:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: tokenized_23, dtype: object
# After Stopword Removal tokenized_0:
# 0    [also, i, point, person, companys, transition...
# 1                                           [hey, mon]
# 2                                                [hey]
# 3             [good, job, joe, well, done, top, notch]
# 4    [okay, look, i, think, tell, rachel, messed, d...
# Name: tokenized_0, dtype: object
# After Stopword Removal tokenized_1:
# 0                           [you, mustve, hand, full]
# 1    [hey-hey-hey, you, wan, na, hear, something, s...
# 2                                                 [hi]
# 3                     [you, liked, you, really, liked]
# 4    [what, what, everybody, its, thanksgiving, .....
# Name: tokenized_1, dtype: object
# After Stopword Removal tokenized_2:
# 0          [that, i, that, i]
# 1               [do, i, ever]
# 2                      [what]
# 3            [oh-ho-ho, yeah]
# 4    [yes, dying, wish, ring]
# Name: tokenized_2, dtype: object
# After Stopword Removal tokenized_3:
# 0                 [so, lets, talk, little, bit, duty]
# 1                  [chris, say, theyre, closing, bar]
# 2         [ah, y'know, building, paper, route, i, ...]
# 3                               [which, part, exactly]
# 4    [see, im, buried, ring, spirit, going, wander...
# Name: tokenized_3, dtype: object
# After Stopword Removal tokenized_4:
# 0           [my, duty, all, right]
# 1                        [no, way]
# 2                             [oh]
# 3     [the, whole, thing, can, go]
# 4    [okay, thats, enough, honey]
# Name: tokenized_4, dtype: object
# After Stopword Removal tokenized_5:
# 0    [now, youll, heading, whole, division, youll...
# 1    [yeah, apparently, theyre, turning, kinda, co...
# 2                                                 [hi]
# 3                       [oh, no-no-no, give, specific]
# 4                     [i, dont, know, let, see, ring]
# Name: tokenized_5, dtype: object
# After Stopword Removal tokenized_6:
# 0                                     [i, see]
# 1         [just, coffee, where, gon, na, hang]
# 2                                         [hi]
# 3    [i, love, specific, specific, best, part]
# 4                                [great, okay]
# Name: tokenized_6, dtype: object
# After Stopword Removal tokenized_7:
# 0    [but, therell, perhaps, 30, people, dump, cer...
# 1                                                [got]
# 2                                          [howd, go]
# 3          [hey, scene, kangaroo, did-did, like, part]
# 4                                         [all, right]
# Name: tokenized_7, dtype: object
# After Stopword Removal tokenized_8:
# 0                                         [good, know]
# 1                                  [can, i, get, beer]
# 2    [oh, well, woman, i, interviewed, pretty, toug...
# 3    [i, surprised, see, kangaroo, world, war, i, e...
# 4                           [thank, thank, thank, and]
# Name: tokenized_8, dtype: object
# After Stopword Removal tokenized_9:
# 0         [we, go, detail]
# 1    [hey, pick, roommate]
# 2             [im, proud]
# 3      [you, fell, asleep]
# 4                       []
# Name: tokenized_9, dtype: object
# After Stopword Removal tokenized_10:
# 0    [no, dont, i, beg]
# 1          [you, betcha]
# 2                   [me]
# 3      [there, kangaroo]
# 4                     []
# Name: tokenized_10, dtype: object
# After Stopword Removal tokenized_11:
# 0    [all, right, well, definite, answer, monday, ...
# 1                                   [is, italian, guy]
# 2    [listen, im, ah, im, sorry, ive, crazy, jea...
# 3                     [they, didnt, take, suggestion]
# 4                                                   []
# Name: tokenized_11, dtype: object
# After Stopword Removal tokenized_12:
# 0                   [really]
# 1       [um-mm, yeah, right]
# 2                  [i, know]
# 3    [thats, coming, buddy]
# 4                         []
# Name: tokenized_12, dtype: object
# After Stopword Removal tokenized_13:
# 0     [absolutely, you, relax, great]
# 1    [oh, god, oh, god, poor, monica]
# 2                              [yeah]
# 3                  [ill, see, later]
# 4                                  []
# Name: tokenized_13, dtype: object
# After Stopword Removal tokenized_14:
# 0    [but, the, waitress, i, went, last, month]
# 1                                        [what]
# 2                                        [yeah]
# 3                                   [dont, go]
# 4                                            []
# Name: tokenized_14, dtype: object
# After Stopword Removal tokenized_15:
# 0    [you, know, forget]
# 1                 [what]
# 2            [ameri-can]
# 3           [im, sorry]
# 4                     []
# Name: tokenized_15, dtype: object
# After Stopword Removal tokenized_16:
# 0    [no-no-no-no, who, talking]
# 1              [he, wrote, poem]
# 2                   [ameri-ccan]
# 3                   [im, sorry]
# 4                             []
# Name: tokenized_16, dtype: object
# After Stopword Removal tokenized_17:
# 0     [no, i-i-i-i, n't, i, actually, n't, know]
# 1    [look, 'my, vessel, empty, nothing, inside]
# 2                      [ameri-can, y'know, its]
# 3                                         [look]
# 4                                             []
# Name: tokenized_17, dtype: object
# After Stopword Removal tokenized_18:
# 0                                            [ok]
# 1    [now, i, 've, touched, seem, emptier, still]
# 2                                     [everybody]
# 3                       [this, guy, fell, asleep]
# 4                                              []
# Name: tokenized_18, dtype: object
# After Stopword Removal tokenized_19:
# 0                    [all, right, well, ...]
# 1    [he, think, monica, empty, empty, vase]
# 2                                         []
# 3                         [he, fell, asleep]
# 4                                         []
# Name: tokenized_19, dtype: object
# After Stopword Removal tokenized_20:
# 0    [i, 'm, gon, na, see, i, get, room, night, i, ...
# 1                          [you, really, think, meant]
# 2                                                   []
# 3                                            [be, mad]
# 4                                                   []
# Name: tokenized_20, dtype: object
# After Stopword Removal tokenized_21:
# 0                         [i, 'll, see, later]
# 1    [oh, totally, oh, god, oh, seemed, happy]
# 2                                           []
# 3                        [or, call, ambulance]
# 4                                           []
# Name: tokenized_21, dtype: object
# After Stopword Removal tokenized_22:
# 0    [yeah, sure]
# 1          [done]
# 2              []
# 3              []
# 4              []
# Name: tokenized_22, dtype: object
# After Stopword Removal tokenized_23:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: tokenized_23, dtype: object
# After Lemmatization tokenized_0:
# 0    [also, i, point, person, companys, transition...
# 1                                           [hey, mon]
# 2                                                [hey]
# 3             [good, job, joe, well, done, top, notch]
# 4    [okay, look, i, think, tell, rachel, messed, d...
# Name: tokenized_0, dtype: object
# After Lemmatization tokenized_1:
# 0                           [you, mustve, hand, full]
# 1    [hey-hey-hey, you, wan, na, hear, something, s...
# 2                                                 [hi]
# 3                     [you, liked, you, really, liked]
# 4    [what, what, everybody, its, thanksgiving, .....
# Name: tokenized_1, dtype: object
# After Lemmatization tokenized_2:
# 0          [that, i, that, i]
# 1               [do, i, ever]
# 2                      [what]
# 3            [oh-ho-ho, yeah]
# 4    [yes, dying, wish, ring]
# Name: tokenized_2, dtype: object
# After Lemmatization tokenized_3:
# 0                 [so, lets, talk, little, bit, duty]
# 1                  [chris, say, theyre, closing, bar]
# 2         [ah, y'know, building, paper, route, i, ...]
# 3                               [which, part, exactly]
# 4    [see, im, buried, ring, spirit, going, wander...
# Name: tokenized_3, dtype: object
# After Lemmatization tokenized_4:
# 0           [my, duty, all, right]
# 1                        [no, way]
# 2                             [oh]
# 3     [the, whole, thing, can, go]
# 4    [okay, thats, enough, honey]
# Name: tokenized_4, dtype: object
# After Lemmatization tokenized_5:
# 0    [now, youll, heading, whole, division, youll...
# 1    [yeah, apparently, theyre, turning, kinda, co...
# 2                                                 [hi]
# 3                       [oh, no-no-no, give, specific]
# 4                     [i, dont, know, let, see, ring]
# Name: tokenized_5, dtype: object
# After Lemmatization tokenized_6:
# 0                                     [i, see]
# 1         [just, coffee, where, gon, na, hang]
# 2                                         [hi]
# 3    [i, love, specific, specific, best, part]
# 4                                [great, okay]
# Name: tokenized_6, dtype: object
# After Lemmatization tokenized_7:
# 0    [but, therell, perhaps, 30, people, dump, cer...
# 1                                                [got]
# 2                                          [howd, go]
# 3          [hey, scene, kangaroo, did-did, like, part]
# 4                                         [all, right]
# Name: tokenized_7, dtype: object
# After Lemmatization tokenized_8:
# 0                                         [good, know]
# 1                                  [can, i, get, beer]
# 2    [oh, well, woman, i, interviewed, pretty, toug...
# 3    [i, surprised, see, kangaroo, world, war, i, e...
# 4                           [thank, thank, thank, and]
# Name: tokenized_8, dtype: object
# After Lemmatization tokenized_9:
# 0         [we, go, detail]
# 1    [hey, pick, roommate]
# 2             [im, proud]
# 3      [you, fell, asleep]
# 4                       []
# Name: tokenized_9, dtype: object
# After Lemmatization tokenized_10:
# 0    [no, dont, i, beg]
# 1          [you, betcha]
# 2                   [me]
# 3      [there, kangaroo]
# 4                     []
# Name: tokenized_10, dtype: object
# After Lemmatization tokenized_11:
# 0    [all, right, well, definite, answer, monday, ...
# 1                                   [is, italian, guy]
# 2    [listen, im, ah, im, sorry, ive, crazy, jea...
# 3                     [they, didnt, take, suggestion]
# 4                                                   []
# Name: tokenized_11, dtype: object
# After Lemmatization tokenized_12:
# 0                   [really]
# 1       [um-mm, yeah, right]
# 2                  [i, know]
# 3    [thats, coming, buddy]
# 4                         []
# Name: tokenized_12, dtype: object
# After Lemmatization tokenized_13:
# 0     [absolutely, you, relax, great]
# 1    [oh, god, oh, god, poor, monica]
# 2                              [yeah]
# 3                  [ill, see, later]
# 4                                  []
# Name: tokenized_13, dtype: object
# After Lemmatization tokenized_14:
# 0    [but, the, waitress, i, went, last, month]
# 1                                        [what]
# 2                                        [yeah]
# 3                                   [dont, go]
# 4                                            []
# Name: tokenized_14, dtype: object
# After Lemmatization tokenized_15:
# 0    [you, know, forget]
# 1                 [what]
# 2            [ameri-can]
# 3           [im, sorry]
# 4                     []
# Name: tokenized_15, dtype: object
# After Lemmatization tokenized_16:
# 0    [no-no-no-no, who, talking]
# 1              [he, wrote, poem]
# 2                   [ameri-ccan]
# 3                   [im, sorry]
# 4                             []
# Name: tokenized_16, dtype: object
# After Lemmatization tokenized_17:
# 0     [no, i-i-i-i, n't, i, actually, n't, know]
# 1    [look, 'my, vessel, empty, nothing, inside]
# 2                      [ameri-can, y'know, its]
# 3                                         [look]
# 4                                             []
# Name: tokenized_17, dtype: object
# After Lemmatization tokenized_18:
# 0                                            [ok]
# 1    [now, i, 've, touched, seem, emptier, still]
# 2                                     [everybody]
# 3                       [this, guy, fell, asleep]
# 4                                              []
# Name: tokenized_18, dtype: object
# After Lemmatization tokenized_19:
# 0                    [all, right, well, ...]
# 1    [he, think, monica, empty, empty, vase]
# 2                                         []
# 3                         [he, fell, asleep]
# 4                                         []
# Name: tokenized_19, dtype: object
# After Lemmatization tokenized_20:
# 0    [i, 'm, gon, na, see, i, get, room, night, i, ...
# 1                          [you, really, think, meant]
# 2                                                   []
# 3                                            [be, mad]
# 4                                                   []
# Name: tokenized_20, dtype: object
# After Lemmatization tokenized_21:
# 0                         [i, 'll, see, later]
# 1    [oh, totally, oh, god, oh, seemed, happy]
# 2                                           []
# 3                        [or, call, ambulance]
# 4                                           []
# Name: tokenized_21, dtype: object
# After Lemmatization tokenized_22:
# 0    [yeah, sure]
# 1          [done]
# 2              []
# 3              []
# 4              []
# Name: tokenized_22, dtype: object
# After Lemmatization tokenized_23:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: tokenized_23, dtype: object
# After Punctuation Removal and Lowercasing tokenized_0:
# 0    [also, i, point, person, companys, transition...
# 1                                           [hey, mon]
# 2                                                [hey]
# 3             [good, job, joe, well, done, top, notch]
# 4    [okay, look, i, think, tell, rachel, messed, d...
# Name: tokenized_0, dtype: object
# After Punctuation Removal and Lowercasing tokenized_1:
# 0                           [you, mustve, hand, full]
# 1    [hey-hey-hey, you, wan, na, hear, something, s...
# 2                                                 [hi]
# 3                     [you, liked, you, really, liked]
# 4    [what, what, everybody, its, thanksgiving, .....
# Name: tokenized_1, dtype: object
# After Punctuation Removal and Lowercasing tokenized_2:
# 0          [that, i, that, i]
# 1               [do, i, ever]
# 2                      [what]
# 3            [oh-ho-ho, yeah]
# 4    [yes, dying, wish, ring]
# Name: tokenized_2, dtype: object
# After Punctuation Removal and Lowercasing tokenized_3:
# 0                 [so, lets, talk, little, bit, duty]
# 1                  [chris, say, theyre, closing, bar]
# 2         [ah, y'know, building, paper, route, i, ...]
# 3                               [which, part, exactly]
# 4    [see, im, buried, ring, spirit, going, wander...
# Name: tokenized_3, dtype: object
# After Punctuation Removal and Lowercasing tokenized_4:
# 0           [my, duty, all, right]
# 1                        [no, way]
# 2                             [oh]
# 3     [the, whole, thing, can, go]
# 4    [okay, thats, enough, honey]
# Name: tokenized_4, dtype: object
# After Punctuation Removal and Lowercasing tokenized_5:
# 0    [now, youll, heading, whole, division, youll...
# 1    [yeah, apparently, theyre, turning, kinda, co...
# 2                                                 [hi]
# 3                       [oh, no-no-no, give, specific]
# 4                     [i, dont, know, let, see, ring]
# Name: tokenized_5, dtype: object
# After Punctuation Removal and Lowercasing tokenized_6:
# 0                                     [i, see]
# 1         [just, coffee, where, gon, na, hang]
# 2                                         [hi]
# 3    [i, love, specific, specific, best, part]
# 4                                [great, okay]
# Name: tokenized_6, dtype: object
# After Punctuation Removal and Lowercasing tokenized_7:
# 0    [but, therell, perhaps, 30, people, dump, cer...
# 1                                                [got]
# 2                                          [howd, go]
# 3          [hey, scene, kangaroo, did-did, like, part]
# 4                                         [all, right]
# Name: tokenized_7, dtype: object
# After Punctuation Removal and Lowercasing tokenized_8:
# 0                                         [good, know]
# 1                                  [can, i, get, beer]
# 2    [oh, well, woman, i, interviewed, pretty, toug...
# 3    [i, surprised, see, kangaroo, world, war, i, e...
# 4                           [thank, thank, thank, and]
# Name: tokenized_8, dtype: object
# After Punctuation Removal and Lowercasing tokenized_9:
# 0         [we, go, detail]
# 1    [hey, pick, roommate]
# 2             [im, proud]
# 3      [you, fell, asleep]
# 4                       []
# Name: tokenized_9, dtype: object
# After Punctuation Removal and Lowercasing tokenized_10:
# 0    [no, dont, i, beg]
# 1          [you, betcha]
# 2                   [me]
# 3      [there, kangaroo]
# 4                     []
# Name: tokenized_10, dtype: object
# After Punctuation Removal and Lowercasing tokenized_11:
# 0    [all, right, well, definite, answer, monday, ...
# 1                                   [is, italian, guy]
# 2    [listen, im, ah, im, sorry, ive, crazy, jea...
# 3                     [they, didnt, take, suggestion]
# 4                                                   []
# Name: tokenized_11, dtype: object
# After Punctuation Removal and Lowercasing tokenized_12:
# 0                   [really]
# 1       [um-mm, yeah, right]
# 2                  [i, know]
# 3    [thats, coming, buddy]
# 4                         []
# Name: tokenized_12, dtype: object
# After Punctuation Removal and Lowercasing tokenized_13:
# 0     [absolutely, you, relax, great]
# 1    [oh, god, oh, god, poor, monica]
# 2                              [yeah]
# 3                  [ill, see, later]
# 4                                  []
# Name: tokenized_13, dtype: object
# After Punctuation Removal and Lowercasing tokenized_14:
# 0    [but, the, waitress, i, went, last, month]
# 1                                        [what]
# 2                                        [yeah]
# 3                                   [dont, go]
# 4                                            []
# Name: tokenized_14, dtype: object
# After Punctuation Removal and Lowercasing tokenized_15:
# 0    [you, know, forget]
# 1                 [what]
# 2            [ameri-can]
# 3           [im, sorry]
# 4                     []
# Name: tokenized_15, dtype: object
# After Punctuation Removal and Lowercasing tokenized_16:
# 0    [no-no-no-no, who, talking]
# 1              [he, wrote, poem]
# 2                   [ameri-ccan]
# 3                   [im, sorry]
# 4                             []
# Name: tokenized_16, dtype: object
# After Punctuation Removal and Lowercasing tokenized_17:
# 0     [no, i-i-i-i, n't, i, actually, n't, know]
# 1    [look, 'my, vessel, empty, nothing, inside]
# 2                      [ameri-can, y'know, its]
# 3                                         [look]
# 4                                             []
# Name: tokenized_17, dtype: object
# After Punctuation Removal and Lowercasing tokenized_18:
# 0                                            [ok]
# 1    [now, i, 've, touched, seem, emptier, still]
# 2                                     [everybody]
# 3                       [this, guy, fell, asleep]
# 4                                              []
# Name: tokenized_18, dtype: object
# After Punctuation Removal and Lowercasing tokenized_19:
# 0                    [all, right, well, ...]
# 1    [he, think, monica, empty, empty, vase]
# 2                                         []
# 3                         [he, fell, asleep]
# 4                                         []
# Name: tokenized_19, dtype: object
# After Punctuation Removal and Lowercasing tokenized_20:
# 0    [i, 'm, gon, na, see, i, get, room, night, i, ...
# 1                          [you, really, think, meant]
# 2                                                   []
# 3                                            [be, mad]
# 4                                                   []
# Name: tokenized_20, dtype: object
# After Punctuation Removal and Lowercasing tokenized_21:
# 0                         [i, 'll, see, later]
# 1    [oh, totally, oh, god, oh, seemed, happy]
# 2                                           []
# 3                        [or, call, ambulance]
# 4                                           []
# Name: tokenized_21, dtype: object
# After Punctuation Removal and Lowercasing tokenized_22:
# 0    [yeah, sure]
# 1          [done]
# 2              []
# 3              []
# 4              []
# Name: tokenized_22, dtype: object
# After Punctuation Removal and Lowercasing tokenized_23:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: tokenized_23, dtype: object

# %%
test_df_backup = test_df.copy()

# %% [markdown]
# ### **Applying Preprocessing on Test Data**

# %%
# Cell 15

# Repeat the preprocessing steps for test_df
for col in json_columns:
    col_name = f'tokenized_{col}'
    test_df[col_name] = test_df[col].apply(lambda x: tokenize_utterances(x, key='utterance'))

for col in tokenized_columns:
    # Pass the stop_words argument using args
    test_df[col] = test_df[col].apply(lambda x: remove_stopwords(x, stop_words))

for col in lemmatized_columns:
    test_df[col] = test_df[col].apply(lambda x: lemmatize_tokens(x, lemmatizer))

for col in processed_columns:
    test_df[col] = test_df[col].apply(lambda x: remove_punctuation_and_lower(x, lowercase=True))

# Combine the tokens into strings for test_df
test_df['combined_text'] = test_df[processed_columns].apply(lambda row: ' '.join([' '.join(tokens) for tokens in row]), axis=1)

# Display the results for verification
print("Processed Test DataFrame:")
print(test_df['combined_text'].head())
# Out:
# Processed Test DataFrame:
# 0    why youre coffee mug number bottom oh thats ...
# 1    come lydia push push 'em push 'em harder harde...
# 2    okay ross n't say elevator uhh yes i n't okay ...
# 3    ohh what it kicked i think baby kicked oh god ...
# 4    previously friends i dont know exactly its-i...
# Name: combined_text, dtype: object

# %% [markdown]
# ## **Step 3 - Transform text into numerical representations using TF-IDF**

# %%
# Cell 16

# Function for TF-IDF Vectorization
def tfidf_vectorization(train_df, test_df, processed_columns):
    # Combine the tokens into strings
    train_df['combined_text'] = train_df[processed_columns].apply(lambda row: ' '.join([' '.join(tokens) for tokens in row]), axis=1)

    # Initialize the TF-IDF Vectorizer
    tfidf_vectorizer = TfidfVectorizer()

    # Fit and transform the combined text for training data
    X_train_tfidf = tfidf_vectorizer.fit_transform(train_df['combined_text'])

    # Transform the combined text for test data using the same vectorizer
    X_test_tfidf = tfidf_vectorizer.transform(test_df['combined_text'])

    return X_train_tfidf, X_test_tfidf, tfidf_vectorizer

# Call the function for TF-IDF Vectorization
X_train_tfidf, X_test_tfidf, tfidf_vectorizer = tfidf_vectorization(train_df, test_df, processed_columns)

# Display the shape of the TF-IDF matrices
print("Shape of X_train_tfidf:", X_train_tfidf.shape)
print("Shape of X_test_tfidf:", X_test_tfidf.shape)

# Display the first few rows of X_train_tfidf
print("\nTF-IDF Matrix (X_train_tfidf):")
print(X_train_tfidf[:5])

# Display the first few rows of X_test_tfidf
print("\nTF-IDF Matrix (X_test_tfidf):")
print(X_test_tfidf[:5])

# Display the vocabulary obtained by the TF-IDF vectorizer
print("\nVocabulary from TF-IDF Vectorizer:")
print(tfidf_vectorizer.vocabulary_)

# Verify the shape of train_df and test_df
print("\nShape of train_df:", train_df.shape)
print("Shape of test_df:", test_df.shape)
# Out:
# Shape of X_train_tfidf: (720, 5052)
# Shape of X_test_tfidf: (200, 5052)
#
# TF-IDF Matrix (X_train_tfidf):
#   (0, 4331)	0.06260397089635425
#   (0, 5005)	0.03263687814614933
#   (0, 2477)	0.08092993939806896
#   (0, 2992)	0.06992332389493973
#   (0, 3732)	0.07686694744013918
#   (0, 1838)	0.040589082865781397
#   (0, 2935)	0.03793345473055903
#   (0, 1877)	0.04153097649390702
#   (0, 3101)	0.07272046232584085
#   (0, 101)	0.06527511600389889
#   (0, 4388)	0.07510522271923223
#   (0, 4898)	0.07198412438942807
#   (0, 1718)	0.09000112361053457
#   (0, 2877)	0.0961214230823993
#   (0, 2473)	0.07198412438942807
#   (0, 4865)	0.07553149239483582
#   (0, 4806)	0.13124199772349157
#   (0, 4456)	0.05964602463169807
#   (0, 1922)	0.05098299441156977
#   (0, 3627)	0.10005251189155775
#   (0, 80)	0.09386943078263818
#   (0, 3590)	0.041450790006018895
#   (0, 4863)	0.06918507438382566
#   (0, 1656)	0.11138308729359002
#   (0, 968)	0.1394514747957197
#   :	:
#   (4, 1381)	0.20171251754013783
#   (4, 5016)	0.08860094649562628
#   (4, 1147)	0.12217997826226817
#   (4, 4626)	0.18850895999101852
#   (4, 4452)	0.1718744447489332
#   (4, 1206)	0.21108059070724675
#   (4, 2794)	0.21108059070724675
#   (4, 3538)	0.09925630109349382
#   (4, 4427)	0.08479352241668697
#   (4, 3102)	0.16500118939350267
#   (4, 4971)	0.1447516089784964
#   (4, 1503)	0.13720322592411982
#   (4, 2288)	0.05675604320238457
#   (4, 4449)	0.2926529732286788
#   (4, 2605)	0.07107011834804226
#   (4, 4878)	0.11201051074201457
#   (4, 1922)	0.08199753709244365
#   (4, 4473)	0.0692088129201266
#   (4, 1292)	0.06879397954332432
#   (4, 2431)	0.04820511646110326
#   (4, 3870)	0.151983587212358
#   (4, 3698)	0.05881339967219827
#   (4, 165)	0.07961374292992555
#   (4, 2528)	0.08524580718312516
#   (4, 4454)	0.060155370023801814
#
# TF-IDF Matrix (X_test_tfidf):
#   (0, 5029)	0.08342362113565688
#   (0, 5005)	0.09125385882720358
#   (0, 4994)	0.11393887580030321
#   (0, 4908)	0.16305009817725316
#   (0, 4887)	0.11161106489554183
#   (0, 4878)	0.048681723595279155
#   (0, 4875)	0.13437943931022203
#   (0, 4863)	0.048360975140602516
#   (0, 4842)	0.08816479206114029
#   (0, 4818)	0.068871980200548
#   (0, 4749)	0.13708948494433904
#   (0, 4730)	0.13437943931022203
#   (0, 4575)	0.19495561335965833
#   (0, 4463)	0.08689240939309242
#   (0, 4459)	0.12977921940697304
#   (0, 4454)	0.10457829633561373
#   (0, 4090)	0.08076341350038783
#   (0, 3877)	0.12461847132090856
#   (0, 3698)	0.10224532135685334
#   (0, 3571)	0.049251930611577226
#   (0, 3538)	0.08627704280453431
#   (0, 3112)	0.06460282545428775
#   (0, 3102)	0.04780826514544727
#   (0, 3092)	0.07489539922272258
#   (0, 3052)	0.2541627869046822
#   :	:
#   (4, 2288)	0.20420730877766538
#   (4, 2155)	0.06813852265948783
#   (4, 2123)	0.484182403134817
#   (4, 2007)	0.1004054825617856
#   (4, 1982)	0.09302220965185595
#   (4, 1967)	0.12368028435203025
#   (4, 1958)	0.05124809507024825
#   (4, 1866)	0.04679891316915929
#   (4, 1813)	0.11124610834210902
#   (4, 1770)	0.16139413437827232
#   (4, 1653)	0.45567869356032636
#   (4, 1567)	0.13565042673244404
#   (4, 1546)	0.1062945166055297
#   (4, 1521)	0.13203822425135797
#   (4, 1517)	0.10990671908661577
#   (4, 1362)	0.12614919020761384
#   (4, 1292)	0.04950392109807189
#   (4, 1198)	0.16139413437827232
#   (4, 870)	0.12890919213627616
#   (4, 608)	0.16139413437827232
#   (4, 476)	0.13565042673244404
#   (4, 392)	0.15189289785344212
#   (4, 230)	0.08460102293265347
#   (4, 199)	0.052226874904332275
#   (4, 140)	0.07677973853085789
#
# Vocabulary from TF-IDF Vectorizer:
# {'also': 179, 'point': 3387, 'person': 3286, 'company': 943, 'transition': 4589, 'kl': 2416, 'gr': 1901, 'system': 4372, 'you': 5029, 'must': 2928, 've': 4749, 'hand': 1982, 'full': 1785, 'that': 4454, 'so': 4064, 'let': 2528, 'talk': 4384, 'little': 2583, 'bit': 474, 'duty': 1377, 'my': 2933, 'all': 165, 'right': 3698, 'now': 3044, 'll': 2587, 'heading': 2030, 'whole': 4901, 'division': 1272, 'lot': 2625, 'see': 3870, 'but': 654, 'there': 4463, 'perhaps': 3279, '30': 33, 'people': 3270, 'dump': 1371, 'certain': 765, 'amount': 194, 'good': 1879, 'know': 2431, 'we': 4844, 'go': 1866, 'detail': 1211, 'no': 3005, 'don': 1292, 'beg': 421, 'definite': 1173, 'answer': 219, 'monday': 2867, 'think': 4473, 'say': 3814, 'confidence': 968, 'fit': 1656, 'well': 4863, 'really': 3590, 'absolutely': 80, 'relax': 3627, 'great': 1922, 'the': 4456, 'waitress': 4806, 'went': 4865, 'last': 2473, 'month': 2877, 'forget': 1718, 'who': 4898, 'talking': 4388, 'actually': 101, 'ok': 3101, 'gon': 1877, 'na': 2935, 'get': 1838, 'room': 3732, 'night': 2992, 'later': 2477, 'yeah': 5005, 'sure': 4331, 'hey': 2065, 'mon': 2864, 'wan': 4816, 'hear': 2034, 'something': 4090, 'suck': 4290, 'do': 1276, 'ever': 1501, 'chris': 841, 'they': 4466, 're': 3571, 'closing': 898, 'bar': 372, 'way': 4842, 'apparently': 242, 'turning': 4639, 'kinda': 2402, 'coffee': 914, 'place': 3353, 'just': 2370, 'where': 4887, 'hang': 1992, 'got': 1895, 'can': 692, 'beer': 420, 'pick': 3326, 'roommate': 3733, 'betcha': 451, 'is': 2281, 'italian': 2289, 'guy': 1958, 'um': 4665, 'mm': 2852, 'oh': 3092, 'god': 1870, 'poor': 3402, 'monica': 2871, 'what': 4878, 'he': 2027, 'wrote': 4995, 'poem': 3384, 'look': 2605, 'vessel': 4758, 'empty': 1444, 'nothing': 3036, 'inside': 2236, 'touched': 4562, 'seem': 3874, 'emptier': 1443, 'still': 4227, 'vase': 4747, 'meant': 2756, 'totally': 4560, 'seemed': 3875, 'happy': 2005, 'done': 1297, 'hi': 2068, 'ah': 140, 'building': 623, 'paper': 3209, 'route': 3741, 'how': 2148, 'woman': 4949, 'interviewed': 2260, 'pretty': 3452, 'tough': 4564, 'thank': 4449, 'mark': 2703, 'coached': 905, 'started': 4194, 'fall': 1568, 'line': 2566, 'wouldn': 4980, 'shut': 3972, 'proud': 3489, 'me': 2750, 'listen': 2576, 'sorry': 4105, 'crazy': 1060, 'jealous': 2314, 'it': 2288, 'like': 2556, 'ameri': 190, 'ccan': 751, 'everybody': 1503, 'job': 2333, 'joe': 2335, 'top': 4552, 'notch': 3033, 'liked': 2557, 'ho': 2095, 'which': 4889, 'part': 3219, 'exactly': 1517, 'thing': 4471, 'give': 1852, 'specific': 4135, 'love': 2633, 'best': 448, 'scene': 3823, 'kangaroo': 2371, 'did': 1224, 'surprised': 4336, 'world': 4971, 'war': 4821, 'epic': 1468, 'fell': 1608, 'asleep': 285, 'didn': 1225, 'take': 4381, 'suggestion': 4300, 'coming': 939, 'buddy': 616, 'this': 4480, 'be': 399, 'mad': 2662, 'or': 3141, 'call': 677, 'ambulance': 189, 'okay': 3102, 'tell': 4427, 'rachel': 3538, 'messed': 2794, 'dessert': 1206, 'thanksgiving': 4452, 'truth': 4626, 'day': 1147, 'yes': 5016, 'dying': 1381, 'wish': 4941, 'ring': 3700, 'buried': 639, 'spirit': 4154, 'going': 1874, 'wander': 4817, 'nether': 2976, 'eternity': 1488, 'enough': 1460, 'honey': 2115, 'and': 199, 'usual': 4732, 'teaching': 4413, 'aerobics': 124, 'partying': 3227, 'much': 2912, 'case': 734, 'wondering': 4956, 'leg': 2516, 'new': 2982, 'james': 2301, 'bond': 519, 'poster': 3419, 'hold': 2098, 'moment': 2861, 'another': 218, 'back': 343, 'together': 4531, 'uh': 4659, 'bout': 550, 'tomorrow': 4540, 'afternoon': 130, 'central': 761, 'perk': 3281, 'village': 4774, 'five': 1658, 'ish': 2283, 'having': 2024, 'phone': 3318, 'finally': 1638, 'paid': 3193, 'even': 1498, 'though': 4486, 'bob': 513, 'impression': 2201, 'thinkin': 4475, 'tomorow': 4539, 'probably': 3462, 'realize': 3588, 'hoping': 2130, 'show': 3964, 'seek': 3873, 'comfort': 935, 'open': 3130, 'arm': 265, 'wry': 4996, 'stranger': 4250, 'next': 2986, 'table': 4375, 'pure': 3510, 'evil': 1509, 'horny': 2135, 'alone': 174, 'nobody': 3006, 'respect': 3661, 'bucket': 614, 'would': 497 ...
#
# Shape of train_df: (720, 49)
# Shape of test_df: (200, 49)

# %% [markdown]
# # **SVM for Emotion Classification**

# %% [markdown]
# ## **Step 1 - Construct an SVM classifier to categorize emotions in text data**

# %%
#Cell 17 - TFIDF
from sklearn.feature_extraction.text import TfidfVectorizer

# Adjusting parameters of TF-IDF
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 5), max_df=0.8, min_df=0.01, max_features=50000000000000)

# Apply TF-IDF to the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(train_df['combined_text'])

# Transform the test data
X_test_tfidf = tfidf_vectorizer.transform(test_df['combined_text'])

# Define the extract_emotion function
def extract_emotion(row):
    if isinstance(row.iloc[0], dict) and 'emotion' in row.iloc[0]:
        return row.iloc[0]['emotion']
    return None

# Extracting Emotion Labels for Training and Test Data
y_train = train_df.apply(extract_emotion, axis=1)
y_test = test_df.apply(extract_emotion, axis=1)

# Verifying the extracted emotion labels and shapes
print("Extracted Emotion Labels for Training Data (First 10 Rows):")
print(y_train.head(10))
print("\nNumber of Rows with no Emotion Label in Training Data:", y_train.isna().sum())
print("\nShape of TF-IDF Matrix for Training Data:", X_train_tfidf.shape)
print("Length of y_train:", len(y_train))

print("\nExtracted Emotion Labels for Test Data (First 10 Rows):")
print(y_test.head(10))
print("\nNumber of Rows with no Emotion Label in Test Data:", y_test.isna().sum())
print("\nShape of TF-IDF Matrix for Test Data:", X_test_tfidf.shape)
print("Length of y_test:", len(y_test))
# Out:
# Extracted Emotion Labels for Training Data (First 10 Rows):
# 0        neutral
# 1        neutral
# 2    non-neutral
# 3            joy
# 4        neutral
# 5        neutral
# 6          anger
# 7    non-neutral
# 8            joy
# 9          anger
# dtype: object
#
# Number of Rows with no Emotion Label in Training Data: 0
#
# Shape of TF-IDF Matrix for Training Data: (720, 1071)
# Length of y_train: 720
#
# Extracted Emotion Labels for Test Data (First 10 Rows):
# 0       surprise
# 1        neutral
# 2        neutral
# 3       surprise
# 4        neutral
# 5    non-neutral
# 6    non-neutral
# 7    non-neutral
# 8    non-neutral
# 9        neutral
# dtype: object
#
# Number of Rows with no Emotion Label in Test Data: 0
#
# Shape of TF-IDF Matrix for Test Data: (200, 1071)
# Length of y_test: 200

# %% [markdown]
# ## **Step 2 - SMOTE Analysis for resampling**

# %%
#Cell 18

from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
import numpy as np  # Import NumPy to convert y_train to array

# Print the shape of the original training data
print("Original training data shape (features):", X_train_tfidf.shape)
print("Original training data shape (labels):", y_train.shape)

# Applying SMOTE to Training Data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_tfidf, np.array(y_train))  # Convert y_train to array

# Print the shape of the training data after applying SMOTE
print("Resampled training data shape (features):", X_train_smote.shape)
print("Resampled training data shape (labels):", y_train_smote.shape)

# Initialize the SVM classifier with class weights
svm_classifier = SVC()
svm_classifier.fit(X_train_smote, y_train_smote)

# Optionally, you can also print a few samples of the resampled labels to see the class distribution
print("Sample of resampled labels:", y_train_smote[:15])

# Count records for each label before SMOTE
label_counts_before = y_train.value_counts()
print("Label counts before SMOTE:")
print(label_counts_before)

# Count records for each label after SMOTE
label_counts_after = pd.Series(y_train_smote).value_counts()
print("Label counts after SMOTE:")
print(label_counts_after)
# Out:
# Original training data shape (features): (720, 1071)
# Original training data shape (labels): (720,)
# Resampled training data shape (features): (2648, 1071)
# Resampled training data shape (labels): (2648,)
# Sample of resampled labels: ['neutral' 'neutral' 'non-neutral' 'joy' 'neutral' 'neutral' 'anger'
#  'non-neutral' 'joy' 'anger' 'joy' 'anger' 'neutral' 'surprise' 'surprise']
# Label counts before SMOTE:
# neutral        331
# joy            128
# non-neutral    107
# surprise        82
# sadness         26
# anger           23
# disgust         14
# fear             9
# Name: count, dtype: int64
# Label counts after SMOTE:
# neutral        331
# non-neutral    331
# joy            331
# anger          331
# surprise       331
# sadness        331
# disgust        331
# fear           331
# Name: count, dtype: int64

# %% [markdown]
# ## **Step 3 - Validate the model using cross-validation and compute classification metrics.**

# %%
# Import the necessary libraries
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC  # Assuming you're using the SVC class for SVM

# Split your data into training and testing sets
# (Your existing code for splitting the data)

# Create an SVM classifier
svm_classifier = SVC(kernel='poly')  # tried rbf and linear as well same results

# Perform cross-validation with k=5 (you can change the number of folds as needed)
cv_scores = cross_val_score(svm_classifier, X_train_tfidf, y_train, cv=5)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)

# Calculate the mean and standard deviation of the cross-validation scores
mean_cv_score = cv_scores.mean()
std_cv_score = cv_scores.std()

# Print the mean and standard deviation
print("Mean CV Score:", mean_cv_score)
print("Standard Deviation of CV Scores:", std_cv_score)

# Train the SVM model on the entire training set
svm_classifier.fit(X_train_tfidf, y_train)

# Evaluate the model on the test set (Your existing code for evaluation)
svm_test_score = svm_classifier.score(X_test_tfidf, y_test)
print("SVM Test Accuracy:", svm_test_score)
# Out:
# Cross-Validation Scores: [0.46527778 0.45833333 0.45833333 0.45833333 0.45833333]
# Mean CV Score: 0.45972222222222225
# Standard Deviation of CV Scores: 0.0027777777777777905
# SVM Test Accuracy: 0.535

# %% [markdown]
# ## **Step 4 - Optimize the classifier by experimenting with different kernels and hyperparameters.**

# %%
# Cell 19

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, make_scorer, f1_score

# Define the parameter grid with different class weight combinations
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly'],
    'class_weight': [None, 'balanced']
    # 'class_weight': [None, {'neutral': 1, 'non-neutral': 5, 'joy': 5, 'anger': 10, 'surprise': 10, 'sadness': 10, 'disgust': 15, 'fear': 15},
    # {'neutral': 1, 'non-neutral': 2, 'joy': 2, 'anger': 5, 'surprise': 5, 'sadness': 5, 'disgust': 7, 'fear': 7}]
    # Add more combinations as needed
}

# Create the SVM classifier
svm_classifier = SVC()

# Define a custom scoring metric (choose one based on your task)
scorer = make_scorer(f1_score, average='weighted')  # Example: Weighted F1 Score

# Create the GridSearchCV object
grid_search = GridSearchCV(svm_classifier, param_grid, cv=2, scoring=scorer)

# Fit the grid search to the data
grid_search.fit(X_train_smote, y_train_smote)

# Get the best estimator
best_classifier = grid_search.best_estimator_

# Evaluate the best classifier on the test data
y_pred_best = best_classifier.predict(X_test_tfidf)
print(y_pred_best)
print("Best Classifier Classification Report:")
print(classification_report(y_test, y_pred_best, zero_division=1))
print("Accuracy Score:")
print(accuracy_score(y_test, y_pred_best))
# Out:
# ['neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'non-neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'surprise' 'neutral' 'neutral' 'neutral']
# Best Classifier Classification Report:
#               precision    recall  f1-score   support
#
#        anger       1.00      0.00      0.00         9
#      disgust       1.00      0.00      0.00         1
#         fear       1.00      0.00      0.00         2
#          joy       1.00      0.00      0.00        24
#      neutral       0.54      0.99      0.70       107
#  non-neutral       1.00      0.03      0.06        35
#      sadness       1.00      0.00      0.00         4
#     surprise       0.00      0.00      1.00        18
#
#     accuracy                           0.54       200
#    macro avg       0.82      0.13      0.22       200
# weighted avg       0.66      0.54      0.47       200
#
# Accuracy Score:
# 0.535

# %% [markdown]
# # **K-Means Clustering**

# %% [markdown]
# ## **Step 1 - Identify the optimal number of clusters with methods like the elbow technique**

# %%
# Cell 20

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Using the TF-IDF features (X_train_smote) to find optimal clusters
wcss = []
for i in range(1, 12):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_train_smote)  # Use X_train_smote instead of X_train_tfidf
    wcss.append(kmeans.inertia_)
print(wcss)

# Plot the WCSS values to observe the elbow
plt.figure(figsize=(8, 6))
plt.plot(range(1, 12), wcss, marker='o', linestyle='-', color='b')
plt.title('WCSS vs. Number of Clusters (k)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()
# Out:
# [1850.1387164878392, 1816.89630603637, 1788.128444058858, 1772.7854955034268, 1750.79250594419, 1731.2801384990673, 1715.239210916271, 1702.1790815266588, 1686.7142265065822, 1671.903966478773, 1652.0743500466617]

# %% [markdown]
# ## **Step 2 - Implement K-Means clustering on the preprocessed text data**

# %%
# Cell 21 (Visualization of Clusters)

from sklearn.decomposition import TruncatedSVD

# Choose the optimal number of clusters from the elbow method
optimal_clusters = 8  # Replace this with the number you find optimal

# Implementing K-Means Clustering
kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(X_train_tfidf)

# Reduce dimensionality for visualization using TruncatedSVD
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X_train_tfidf)

# Visualize the clusters
plt.figure(figsize=(10, 8))
for i in range(optimal_clusters):
    plt.scatter(X_svd[y_kmeans == i, 0], X_svd[y_kmeans == i, 1], label=f'Cluster {i + 1}')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', marker='X', label='Centroids')
plt.title('K-Means Clustering - 2D Visualization')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.show()

# %% [markdown]
# ## **Step 3 - Interpret the clusters to find patterns corresponding to different emotions.**

# %%
# Function to print top terms per cluster
def print_top_terms_per_cluster(vectorizer, kmeans, n_terms=10):
    """
    Print the top terms per cluster based on the fitted TF-IDF vectorizer and K-Means clustering model.

    Parameters:
    - vectorizer: The fitted TF-IDF vectorizer.
    - kmeans: The fitted K-Means clustering model.
    - n_terms: Number of top terms to display per cluster (default is 10).
    """
    # Get the indices of terms in descending order of importance for each cluster
    order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
    # Get the feature names (terms) from the TF-IDF vectorizer
    terms = vectorizer.get_feature_names_out()
    # Print top terms for each cluster
    for i in range(len(kmeans.cluster_centers_)):
        print("Cluster %d top terms:" % i, end='')
        # Calculate the actual number of terms to display (up to n_terms or the number of available terms)
        num_terms_to_display = min(n_terms, len(terms))
        for ind in order_centroids[i, :num_terms_to_display]:
            print(' %s' % terms[ind], end=', ')
        print("\n")

# %% [markdown]
# # **Model Insights**

# %% [markdown]
# ## **Step 1 - Analyze the performance of the SVM classifier on Holdout Dataset**

# %%
# Apply tokenization to each JSON column in holdout_df
for col in json_columns:
    col_name = f'tokenized_{col}'
    holdout_df[col_name] = holdout_df[col].apply(lambda x: tokenize_utterances(x, key='utterance'))

# Display the results for verification
print("Modified Holdout DataFrame:")
print(holdout_df[[f'tokenized_{col}' for col in json_columns]].head())

from sklearn.feature_extraction.text import TfidfVectorizer

# Function for TF-IDF Vectorization
def tfidf_vectorization(train_df, holdout_df, processed_columns):
    # Combine the tokens into strings for train and holdout data
    train_df['combined_text'] = train_df[processed_columns].apply(lambda row: ' '.join([' '.join(tokens) for tokens in row]), axis=1)
    holdout_df['combined_text'] = holdout_df[processed_columns].apply(lambda row: ' '.join([' '.join(tokens) for tokens in row]), axis=1)

    # Initialize the TF-IDF Vectorizer
    tfidf_vectorizer = TfidfVectorizer()

    # Fit and transform the combined text for training data
    X_train_tfidf = tfidf_vectorizer.fit_transform(train_df['combined_text'])

    # Transform the combined text for holdout data using the same vectorizer
    X_holdout_tfidf = tfidf_vectorizer.transform(holdout_df['combined_text'])

    return X_train_tfidf, X_holdout_tfidf, tfidf_vectorizer

# Call the function for TF-IDF Vectorization
X_train_tfidf, X_holdout_tfidf, tfidf_vectorizer = tfidf_vectorization(train_df, holdout_df, processed_columns)

# Display the shape of the TF-IDF matrices
print("Shape of X_train_tfidf:", X_train_tfidf.shape)
print("Shape of X_holdout_tfidf:", X_holdout_tfidf.shape)
# Out:
# Modified Holdout DataFrame:
#                                          tokenized_0  \
# 0  [Oh, my, God, ,, hes, lost, it, ., Hes, tota...
# 1                          [Hey, Estelle, ,, listen]
# 2     [Yes, ?, Yes, ?, !, How, can, I, help, you, ?]
# 3  [You, had, no, right, to, tell, me, you, ever,...
# 4  [Oh, ,, it, 's, so, romantic, to, send, people...
#
#                                          tokenized_1  \
# 0                                          [What, ?]
# 1  [Well, !, Well, !, Well, !, Joey, Tribbiani, !...
# 2  [Yeah, ,, we, were, we, were, just, looking, a...
# 3                                          [What, ?]
# 4  [Yknow, ,, Monica, and, Chandler, are, marrie...
#
#                                          tokenized_2  \
# 0  [Or, !, Or, ,, we, could, go, to, the, bank, ,...
# 1  [What, are, you, talkin, about, ?, I, never, ...
# 2     [Oh-oh, ,, youre-youre, fellow, scholars, .]
# 3  [I, was, doing, great, with, Julie, before, I,...
# 4                 [All, in, good, time, my, love, .]
#
#                                          tokenized_3  \
# 0                             [Youre, a, genius, !]
# 1                                     [Really, ?, !]
# 2  [What, exactly, were, you, looking, for, ,, hm...
# 3  [Hey, ,, I, was, doin, ', great, before, I, fo...
# 4                           [All, in, good, time, .]
#
#                                          tokenized_4  \
# 0  [Aww, ,, man, ,, now, we, wont, be, bank, bud...
# 1                                          [Yeah, !]
# 2  [Perhaps, ,, perhaps, Dr., Chester, Stocks, m...
# 3                           [The, point, is, I, ...]
# 4                                     [Oh, shoot, !]
#
#                                       tokenized_5  \
# 0              [Now, ,, theres, two, reasons, .]
# 1         [Oh, well, ,, no, harm, ,, no, foul, .]
# 2                                        [Uhh, .]
# 3  [I, do, n't, need, this, right, now, ,, OK, .]
# 4  [I, left, my, guitar, in, their, apartment, .]
#
#                                          tokenized_6  \
# 0                                           [Hey, .]
# 1             [Okay, ,, you, guys, free, tonight, ?]
# 2  [Ah, Ah, Get, out, of, here, !, Uh, ,, meeting...
# 3  [It, ,, it, 's, too, late, ,, I, 'm, with, som...
# 4            [Well, you, can, let, me, in, later, .]
#
#                                          tokenized_7  \
# 0                                           [Hey, !]
# 1                                       [Yeah, !, !]
# 2  [Uh, ,, actually, I, find, Marions, views, fa...
# 3                       [This, ship, has, sailed, .]
# 4  [I, dont, have, a, key, ,, they, took, mine, ...
#
#                                          tokenized_8  \
# 0  [Ohh, ,, you, guys, ,, remember, that, cute, c...
# 1  [Tonight, ?, You-you, did, n't, say, it, was, ...
# 2  [I, find, Marions, views, far, too, progressi...
# 3  [Alright, ,, fine, ,, you, go, ahead, and, you...
# 4  [What, ?, !, They, took, mine, to, give, to, y...
#
#                                     tokenized_9  ...  \
# 0                                 [Where, ?, !]  ...
# 1                                            []  ...
# 2             [Im, sorry, ,, who, are, you, ?]  ...
# 3                                     [Fine, .]  ...
# 4  [Why, would, they, take, away, our, keys, ?]  ...
#
#                                         tokenized_14  \
# 0  [Well, ,, next, time, your, massaging, him, ,,...
# 1                                                 []
# 2      [Well, I, uh, ,, I, skipped, forth, grade, .]
# 3                                                 []
# 4                                   [Uh, ,, what, ?]
#
#                                         tokenized_15  \
# 0  [Yeah, !, Yeah, !, Yeah, !, Like-like, when, I...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Yes, !, Shes, gon, na, help, us, take, care,...
#
#                      tokenized_16  \
# 0        [Thank, you, ,, Joey, .]
# 1                              []
# 2                              []
# 3                              []
# 4  [WhatYoure, not, serious, .]
#
#                                         tokenized_17  \
# 0                          [No-no, ,, thank, you, .]
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [I, mean, shes, a, very, nice, woman, ,, but,...
#
#                              tokenized_18   tokenized_19     tokenized_20  \
# 0                                      []             []               []
# 1                                      []             []               []
# 2                                      []             []               []
# 3                                      []             []               []
# 4  [Shell, drive, us, totally, crazy, .]  [Hi, Ross, !]  [Hi, roomie, !]
#
#   tokenized_21 tokenized_22 tokenized_23
# 0           []           []           []
# 1           []           []           []
# 2           []           []           []
# 3           []           []           []
# 4           []           []           []
#
# [5 rows x 24 columns]
# Shape of X_train_tfidf: (720, 5052)
# Shape of X_holdout_tfidf: (80, 5052)

# %%
# Example code for fitting SVM classifier
svm_classifier = SVC()
svm_classifier.fit(X_train_tfidf, y_train)

y_holdout = holdout_df.apply(extract_emotion, axis=1)
# Example code for generating predictions on the holdout data
y_pred_holdout = svm_classifier.predict(X_holdout_tfidf)

# Print the classification report and accuracy of the SVM classifier on holdout data
print("SVM Classifier - Classification Report on Holdout Dataset:")
print(classification_report(y_holdout, y_pred_holdout, zero_division=1))
print("SVM Classifier - Accuracy Score on Holdout Dataset:")
print(accuracy_score(y_holdout, y_pred_holdout))
# Out:
# SVM Classifier - Classification Report on Holdout Dataset:
#               precision    recall  f1-score   support
#
#        anger       1.00      0.00      0.00         6
#         fear       1.00      0.00      0.00         1
#          joy       1.00      0.00      0.00        16
#      neutral       0.42      1.00      0.60        34
#  non-neutral       1.00      0.00      0.00        11
#      sadness       1.00      0.00      0.00         2
#     surprise       1.00      0.00      0.00        10
#
#     accuracy                           0.42        80
#    macro avg       0.92      0.14      0.09        80
# weighted avg       0.76      0.42      0.25        80
#
# SVM Classifier - Accuracy Score on Holdout Dataset:
# 0.425

# %% [markdown]
# ## **Step 2 - Analyze the clusters formed by K-Means.**

# %%
# Cell 24

# Assuming you have clusters and emotion labels defined
cluster_emotion_mapping = {
    0: "joy",
    1: "non-neutral",
    2: "neutral",
    3: "non-neutral",
    4: "non-neutral",
    5: "neutral",
    6: "surprise",
    7: "non-neutral"
}

# Assign emotions to clusters based on your criteria
cluster_emotions = {}
for cluster_id, emotion_label in cluster_emotion_mapping.items():
    cluster_emotions[cluster_id] = emotion_label

# Print cluster-emotion assignments
for cluster_id, emotion in cluster_emotions.items():
    print(f"Cluster {cluster_id}: Emotion - {emotion}")
# Out:
# Cluster 0: Emotion - joy
# Cluster 1: Emotion - non-neutral
# Cluster 2: Emotion - neutral
# Cluster 3: Emotion - non-neutral
# Cluster 4: Emotion - non-neutral
# Cluster 5: Emotion - neutral
# Cluster 6: Emotion - surprise
# Cluster 7: Emotion - non-neutral

# %% [markdown]
# ## **Step 3 - Compare and contrast the results obtained from both SVM and K-Means also insights into the emotional trends captured by the models**

# %%
# Cell 25

from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'X_train_tfidf' is your TF-IDF matrix
# Assuming 'cluster_labels' contains cluster assignments
# Assuming 'cluster_emotions' contains emotion labels

# Map emotion labels to numeric values
emotion_to_numeric = {
    "joy": 0,
    "non-neutral": 1,
    "neutral": 2,
    "surprise": 3,
    "anger": 4,
    "sadness": 5,
    "disgust": 6,
    "fear": 7
}
numeric_emotions = [emotion_to_numeric[cluster_emotions[cluster_id]] for cluster_id in sorted(np.unique(y_kmeans))]


# Perform Truncated SVD for dimensionality reduction
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X_train_tfidf)

# Create a scatter plot to visualize clusters
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_svd[:, 0], X_svd[:, 1], c=y_kmeans, cmap='viridis')

# # Create a legend with cluster numbers
# legend_labels = [f"Cluster {label}" for label in cluster_emotions.keys()]  # Use cluster numbers instead of emotion labels

# # Add the legend
# handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=c, markersize=10) for c in scatter.cmap(np.unique(scatter.to_rgba(numeric_emotions)))]
# plt.legend(handles, legend_labels, title='Cluster Legend', loc='upper right')

plt.title("Cluster Visualization with Cluster Numbers")
plt.xlabel("SVD Dimension 1")
plt.ylabel("SVD Dimension 2")
plt.show()
# Cell 26

# %%
# Cell 26

# Assuming 'X_train_tfidf' is your TF-IDF matrix
# Assuming 'y_kmeans' contains cluster assignments
# Assuming 'cluster_labels' contains emotion labels

# Mapping clusters to emotion labels
cluster_emotions = {
    0: "non-neutral",
    1: "neutral",
    2: "joy",
    3: "non-neutral",
    4: "non-neutral",
    5: "neutral",
    6: "surprise",
    7: "non-neutral"
}

# Convert emotion labels to numeric values based on the mapping
numeric_emotions = [emotion_to_numeric[cluster_emotions[cluster_id]] for cluster_id in sorted(np.unique(y_kmeans))]


# Perform Truncated SVD for dimensionality reduction
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X_train_tfidf)

# Create a scatter plot for each non-empty cluster
fig, axs = plt.subplots(2, 4, figsize=(16, 8), sharex=True, sharey=True)
axs = axs.flatten()

# Get the unique colors from the viridis color map for the clusters
cluster_colors = [plt.cm.viridis(i) for i in np.linspace(0, 1, len(np.unique(y_kmeans)))]

# ...

for cluster_id, ax, color in zip(sorted(np.unique(y_kmeans)), axs, cluster_colors):
    cluster_mask = y_kmeans == cluster_id
    if np.any(cluster_mask):
        ax.scatter(X_svd[cluster_mask, 0], X_svd[cluster_mask, 1], c=[color], label=f'Cluster {cluster_id}')
        ax.set_title(f"Cluster {cluster_id}")

# Add a common legend
fig.legend(title='Cluster Legend', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# cell 27

# Assuming 'y_kmeans' contains K-Means cluster assignments (0 to 7)
# Assuming 'cluster_emotion_mapping' is the dictionary defined in Cell 23

# Create empty lists to store aligned emotional labels and cluster assignments
aligned_emotional_labels = []
cluster_assignments = []

# Iterate through K-Means cluster assignments
for cluster_assignment in y_kmeans:
    # Map the cluster assignment to the corresponding emotional label
    emotional_label = cluster_emotion_mapping.get(cluster_assignment, "Unknown")
    # Append the aligned emotional label to the list
    aligned_emotional_labels.append(emotional_label)
    # Append the cluster assignment to the list
    cluster_assignments.append(cluster_assignment)

# Verify the aligned emotional labels and cluster assignments by printing them
print("Aligned Emotional Labels:")
print(aligned_emotional_labels)

print("Cluster Assignments:")
print(cluster_assignments)
# Out:
# Aligned Emotional Labels:
# ['non-neutral', 'joy', 'non-neutral', 'non-neutral', 'non-neutral', 'joy', 'neutral', 'non-neutral', 'neutral', 'joy', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'joy', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'joy', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'non-neutral', 'non-neutral', 'non-neutral', 'joy', 'neutral', 'non-neutral', 'neutral', 'neutral', 'surprise', 'joy', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'joy', 'neutral', 'neutral', 'neutral', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'joy', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'neutral', 'non-neutral', 'neutral', 'joy', 'neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'joy', 'neutral', 'joy', 'neutral', 'non-neutral', 'joy', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'joy', 'surprise', 'neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'neutral', 'joy', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'surprise', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'joy', 'neutral', 'neutral', 'neutral', 'joy', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'surprise', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'surprise', 'neutral', 'neutral', 'neutral', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'joy', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'joy', 'non-neutral', 'neutral', 'surprise', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'joy', 'neutral', 'neutral', 'joy', 'non-neutral', 'neutral', 'non-neutral', 'joy', 'neutral', 'joy', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'joy', 'non-neutral', 'neutral', 'non-neutral', 'joy', 'neutral', 'surprise', 'non-neutral', 'neutral', 'joy', 'joy', 'non-neutral', 'neutral', 'neutral', 'neutral', 'non-neutral', 'non-neutral', 'joy', 'non-neutral', 'non-neutral', 'neutral', 'neutral', 'joy', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'non-neutral', 'neutral', 'joy', 'joy', 'non-neutral', 'neutral', 'neutral', 'non-neutral',  ...
# Cluster Assignments:
# [3, 0, 7, 3, 1, 0, 5, 7, 2, 0, 2, 5, 3, 2, 2, 5, 4, 1, 2, 2, 4, 2, 5, 4, 1, 4, 2, 7, 5, 2, 4, 2, 2, 5, 7, 2, 4, 2, 4, 4, 0, 2, 2, 7, 7, 4, 2, 4, 0, 5, 2, 3, 3, 2, 4, 0, 4, 4, 2, 4, 4, 4, 5, 2, 2, 7, 2, 2, 2, 4, 5, 7, 2, 4, 7, 5, 4, 3, 5, 2, 0, 4, 3, 3, 0, 2, 4, 5, 2, 6, 0, 2, 2, 2, 2, 2, 0, 5, 5, 2, 0, 1, 1, 5, 2, 0, 0, 0, 4, 4, 2, 1, 3, 2, 7, 5, 5, 0, 5, 1, 2, 0, 2, 4, 2, 2, 4, 0, 2, 0, 2, 4, 0, 2, 7, 4, 3, 4, 2, 5, 7, 2, 7, 2, 0, 6, 2, 4, 2, 2, 0, 5, 0, 7, 2, 2, 2, 5, 5, 5, 4, 5, 2, 5, 5, 2, 4, 4, 6, 5, 2, 4, 7, 4, 4, 4, 5, 0, 5, 2, 2, 0, 2, 4, 7, 5, 5, 2, 7, 2, 4, 3, 5, 2, 3, 4, 7, 6, 4, 7, 7, 2, 2, 5, 2, 6, 2, 2, 2, 0, 4, 7, 2, 2, 2, 2, 7, 4, 5, 2, 4, 7, 2, 2, 2, 0, 4, 4, 2, 2, 2, 2, 7, 4, 7, 2, 3, 4, 2, 3, 7, 2, 5, 2, 5, 5, 2, 2, 2, 2, 7, 2, 2, 4, 5, 2, 0, 0, 4, 2, 7, 2, 2, 2, 0, 7, 5, 6, 2, 7, 4, 4, 4, 1, 0, 2, 2, 0, 7, 2, 7, 0, 5, 0, 7, 5, 7, 2, 2, 2, 2, 7, 0, 4, 5, 3, 0, 5, 6, 4, 2, 0, 0, 3, 2, 5, 2, 4, 4, 0, 4, 7, 2, 2, 0, 2, 3, 5, 7, 2, 3, 7, 7, 4, 1, 2, 0, 0, 7, 2, 2, 7, 5, 0, 2, 5, 0, 4, 0, 2, 2, 4, 2, 1, 4, 2, 2, 2, 2, 6, 0, 2, 2, 4, 0, 5, 4, 4, 2, 4, 0, 7, 2, 4, 2, 7, 5, 5, 2, 4, 2, 7, 2, 0, 7, 0, 5, 7, 2, 0, 2, 2, 2, 3, 0, 7, 1, 2, 2, 0, 5, 1, 5, 5, 4, 5, 1, 3, 4, 4, 0, 4, 2, 2, 3, 5, 2, 1, 4, 2, 2, 2, 2, 2, 2, 2, 0, 7, 5, 0, 0, 2, 4, 2, 7, 7, 4, 0, 2, 4, 5, 4, 0, 2, 7, 4, 0, 5, 7, 2, 2, 1, 0, 4, 2, 5, 3, 4, 0, 1, 7, 2, 3, 0, 2, 2, 1, 7, 4, 2, 4, 7, 3, 4, 5, 0, 2, 2, 5, 0, 4, 2, 7, 1, 4, 0, 2, 4, 1, 2, 0, 4, 5, 4, 5, 3, 7, 7, 0, 3, 2, 7, 6, 2, 3, 2, 7, 3, 2, 7, 2, 7, 7, 6, 5, 4, 2, 0, 6, 4, 4, 4, 7, 6, 2, 4, 2, 7, 5, 0, 3, 2, 0, 7, 4, 4, 2, 0, 7, 2, 2, 2, 2, 2, 7, 3, 5, 2, 4, 0, 2, 4, 5, 2, 4, 5, 4, 6, 4, 7, 3, 3, 3, 2, 0, 4, 4, 5, 2, 3, 5, 2, 0, 7, 0, 7, 7, 2, 2, 2, 4, 7, 3, 0, 4, 2, 4, 2, 2, 4, 0, 4, 4, 2, 4, 7, 3, 4, 4, 2, 5, 0, 5, 1, 2, 2, 2, 4, 4, 4, 0, 2, 7, 7, 7, 2, 4, 3, 4, 0, 0, 2, 3, 6, 4, 0, 4, 3, 6, 2, 2, 2, 5, 3, 2, 2, 2, 5, 5, 2, 4, 6, 7, 3, 2, 2, 4, 5, 7, 4, 7, 2, 2, 4, 2, 2, 7, 4, 2, 2, 5, 0, 2, 2, 7, 4, 3, 0, 4, 2, 4, 5, 2, 4, 7, 2, 0, 2, 7, 2, 5, 7, 2, 5, 2, 2, 5, 4, 7, 7, 4, 4, 2, 7, 7, 5, 2, 2, 2, 2, 2, 7, 5, 3, 4, 2, 0, 3, 7, 2, 4, 1, 4, 0, 2, 2, 2, 7, 3, 5, 4, 0, 2, 2, 2, 2, 2, 7, 7, 2]

# %%
# Create empty lists to store the data
document_ids = []
svm_predicted_emotions = []
y_kmeans = []
cluster_emotions = []

# Mapping clusters to emotion labels
cluster_emotions_mapping = {
    0: "non-neutral",
    1: "neutral",
    2: "joy",
    3: "non-neutral",
    4: "non-neutral",
    5: "neutral",
    6: "surprise",
    7: "non-neutral"
}
# Iterate through the DataFrame rows
for i in range(0, 720):  # Use the length of aligned_emotional_labels as the loop range
    # Extract the relevant information from the JSON objects in each row
    document_id = i  # You can use the loop index as Document ID
    svm_predicted_emotion = y_train[i]
    k_means_cluster = cluster_assignments[i]
    cluster_emotion = cluster_emotions_mapping.get(k_means_cluster, "Unknown")

    
    document_ids.append(document_id)
    svm_predicted_emotions.append(svm_predicted_emotion)
    y_kmeans.append(k_means_cluster)
    cluster_emotions.append(cluster_emotion)
    
# Create a DataFrame to store the findings
findings_df = pd.DataFrame({
    'Document ID': document_ids,
    'SVM Predicted Emotion': svm_predicted_emotions,
    'K-Means Cluster': y_kmeans,
    'Cluster Emotion': cluster_emotions,
    'SVM Matches Cluster Emotion': (findings_df['SVM Predicted Emotion'] == findings_df['Cluster Emotion'])
})

# Display the table
print("Table summarizing the findings:")
print(findings_df)
# Out:
# Table summarizing the findings:
#      Document ID SVM Predicted Emotion  K-Means Cluster Cluster Emotion  \
# 0              0               neutral                3     non-neutral
# 1              1               neutral                0     non-neutral
# 2              2           non-neutral                7     non-neutral
# 3              3                   joy                3     non-neutral
# 4              4               neutral                1         neutral
# ..           ...                   ...              ...             ...
# 715          715                   joy                2             joy
# 716          716               neutral                2             joy
# 717          717               neutral                7     non-neutral
# 718          718                   joy                7     non-neutral
# 719          719               neutral                2             joy
#
#      SVM Matches Cluster Emotion
# 0                          False
# 1                          False
# 2                           True
# 3                          False
# 4                           True
# ..                           ...
# 715                         True
# 716                        False
# 717                        False
# 718                        False
# 719                        False
#
# [720 rows x 5 columns]

# %%
findings_df.head(50)
# Out:
#     Document ID SVM Predicted Emotion  K-Means Cluster Cluster Emotion  \
# 0             0               neutral                3     non-neutral
# 1             1               neutral                0     non-neutral
# 2             2           non-neutral                7     non-neutral
# 3             3                   joy                3     non-neutral
# 4             4               neutral                1         neutral
# 5             5               neutral                0     non-neutral
# 6             6                 anger                5         neutral
# 7             7           non-neutral                7     non-neutral
# 8             8                   joy                2             joy
# 9             9                 anger                0     non-neutral
# 10           10                   joy                2             joy
# 11           11                 anger                5         neutral
# 12           12               neutral                3     non-neutral
# 13           13              surprise                2             joy
# 14           14              surprise                2             joy
# 15           15                   joy                5         neutral
# 16           16           non-neutral                4     non-neutral
# 17           17           non-neutral                1         neutral
# 18           18              surprise                2             joy
# 19           19               neutral                2             joy
# 20           20              surprise                4     non-neutral
# 21           21           non-neutral                2             joy
# 22           22               neutral                5         neutral
# 23           23              surprise                4     non-neutral
# 24           24               neutral                1         neutral
# 25           25               neutral                4     non-neutral
# 26           26               neutral                2             joy
# 27           27           non-neutral                7     non-neutral
# 28           28           non-neutral                5         neutral
# 29           29               sadness                2             joy
# 30           30               neutral                4     non-neutral
# 31           31               neutral                2             joy
# 32           32               sadness                2             joy
# 33           33               neutral                5         neutral
# 34           34               neutral                7     non-neutral
# 35           35                   joy                2             joy
# 36           36               neutral                4     non-neutral
# 37           37                   joy                2             joy
# 38           38           non-neutral                4     non-neutral
# 39           39                   joy                4     non-neutral
# 40           40              surprise                0     non-neutral
# 41           41           non-neutral                2             joy
# 42           42               neutral                2             joy
# 43           43               neutral                7     non-neutral
# 44           44                   joy                7     non-neutral
# 45           45                   joy                4     non-neutral
# 46           46           non-neutral                2             joy
# 47           47              surprise                4     non-neutral
# 48           48               disgust                0     non-neutral
# 49           49           non-neutral                5         neutral
#
#     SVM Matches Cluster Emotion
# 0                         False
# 1                         False
# 2                          True
# 3                         False
# 4                          True
# 5                         False
# 6                         False
# 7                          True
# 8                          True
# 9                         False
# 10                         True
# 11                        False
# 12                        False
# 13                        False
# 14                        False
# 15                        False
# 16                         True
# 17                        False
# 18                        False
# 19                        False
# 20                        False
# 21                        False
# 22                         True
# 23                        False
# 24                         True
# 25                        False
# 26                        False
# 27                         True
# 28                        False
# 29                        False
# 30                        False
# 31                        False
# 32                        False
# 33                         True
# 34                        False
# 35                         True
# 36                        False
# 37                         True
# 38                         True
# 39                        False
# 40                        False
# 41                        False
# 42                        False
# 43                        False
# 44                        False
# 45                        False
# 46                        False
# 47                        False
# 48                        False
# 49                        False

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame 'findings_df' with columns 'K-Means Cluster', 'SVM Predicted Emotion', and 'Cluster Emotion'

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(x='K-Means Cluster', y='SVM Predicted Emotion', hue='Cluster Emotion', data=findings_df, palette='Set1')

# Add labels and a legend
plt.xlabel('K-Means Cluster')
plt.ylabel('SVM Predicted Emotion')
plt.title('Scatter Plot of K-Means Clusters vs. SVM Predicted Emotions')

# Move the legend outside the plot
plt.legend(title='Cluster Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()  # Ensures the legend is not cut off
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame 'findings_df' with columns 'K-Means Cluster' and 'SVM Predicted Emotion'

# Group the data by K-Means clusters and SVM predicted emotions
grouped = findings_df.groupby(['K-Means Cluster', 'SVM Predicted Emotion']).size().unstack(fill_value=0)

# Get a list of unique K-Means clusters
clusters = sorted(findings_df['K-Means Cluster'].unique())

# Create a bar chart for each cluster
plt.figure(figsize=(14, 8))
for cluster in clusters:
    emotions = grouped.loc[cluster].index
    counts = grouped.loc[cluster].values
    plt.bar(emotions, counts, label=f'Cluster {cluster}')

# Add labels and title
plt.xlabel('SVM Predicted Emotion')
plt.ylabel('Count')
plt.title('Distribution of SVM Predicted Emotions within Each K-Means Cluster')

# Add a legend
plt.legend(title='K-Means Cluster', loc='upper right')

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import confusion_matrix

# Assuming you have a DataFrame 'findings_df' with columns 'K-Means Cluster' and 'SVM Predicted Emotion'

# Create a confusion matrix
confusion = pd.crosstab(findings_df['K-Means Cluster'], findings_df['SVM Predicted Emotion'])

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')

# Add labels and title
plt.xlabel('SVM Predicted Emotion')
plt.ylabel('K-Means Cluster')
plt.title('SVM Predictions vs. K-Means Clusters')

# Show the plot
plt.show()
